# %% [markdown]
# # GAN for Molecular Generation Task

# %% [markdown]
# ## GAN Model

# %%
import numpy as np
import tensorflow as tf
import warnings

# %%
LENGTH = 128
DFF = 32

# shape: (batch_size, length, dff)
cb2_embeddings = np.load("./data/processed_d2.npy")
cb2_embeddings = tf.expand_dims(cb2_embeddings, axis=-1)
cb2_embeddings = tf.cast(cb2_embeddings, dtype=tf.float32)

cb2_embeddings.shape, tf.math.reduce_min(cb2_embeddings), tf.math.reduce_max(cb2_embeddings), tf.math.reduce_mean(cb2_embeddings)
# Out:
# (TensorShape([7252, 128, 32, 1]),
#  <tf.Tensor: shape=(), dtype=float32, numpy=-3.55868>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=3.7089498>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.0027595111>)

# %%
from tensorflow.keras import layers

def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(8 * 8 * 256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((8, 8, 256)))
    assert model.output_shape == (None, 8, 8, 256)  # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(2, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 16, 8, 128)

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 32, 16, 64)

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(4, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 128, 32, 1)

    return model

generator = make_generator_model()
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16384)             1638400
#
#  batch_normalization (Batch  (None, 16384)             65536
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 16384)             0
#
#  reshape (Reshape)           (None, 8, 8, 256)         0
#
#  conv2d_transpose (Conv2DTr  (None, 16, 8, 128)        819200
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 16, 64)        204800
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 32, 1)        1600
#  Transpose)
#
# =================================================================
# Total params: 2729536 (10.41 MB)
# Trainable params: 2696768 (10.29 MB)
# Non-trainable params: 32768 (128.00 KB)
# _________________________________________________________________

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[128, 32, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(256, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

discriminator = make_discriminator_model()
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 16, 64)        1664
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 16, 64)        0
#
#  dropout (Dropout)           (None, 64, 16, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 8, 128)        204928
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 8, 128)        0
#
#  dropout_1 (Dropout)         (None, 32, 8, 128)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 4, 256)        819456
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 4, 256)        0
#
#  dropout_2 (Dropout)         (None, 16, 4, 256)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense_1 (Dense)             (None, 1)                 16385
#
# =================================================================
# Total params: 1042433 (3.98 MB)
# Trainable params: 1042433 (3.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()
def discriminator_loss(real_output, fake_output):
    # fake_loss = -tf.reduce_mean(fake_output)
    # real_loss = -tf.reduce_mean(fake_output)
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    # return -tf.reduce_mean(fake_output)
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.legacy.Adam(.1)
discriminator_optimizer = tf.keras.optimizers.legacy.Adam(1e-6)

# %%
EPOCHS = 150
noise_dim = 100
num_examples_to_generate = 16

seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
def reward_valid_smiles(smiles):
    return tf.numpy_function(is_valid_smiles, [smiles], tf.int64)

def penalize_invalid_smiles(smiles):
    return tf.numpy_function(is_not_valid_smiles, [smiles], tf.int64)

# %%
@tf.function
def train_step(images):
    BATCH_SIZE = 8
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        # Wasserstein Loss for Generator
        gen_loss = -tf.reduce_mean(fake_output)

        # Wasserstein Loss for Discriminator
        disc_loss = tf.reduce_mean(fake_output) - tf.reduce_mean(real_output)

        # Gradient Penalty (Optional but can improve WGAN training)
        epsilon = tf.random.uniform(shape=[BATCH_SIZE, 1, 1, 1], minval=0.0, maxval=1.0)
        epsilon = tf.broadcast_to(epsilon, images.shape)  # Match the shape of epsilon to images
        interpolated_images = epsilon * images + (1 - epsilon) * generated_images
        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated_images)
            pred_interpolated = discriminator(interpolated_images, training=True)
        gradients = gp_tape.gradient(pred_interpolated, interpolated_images)
        gradients_l2 = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1, 2, 3]))
        gradient_penalty = tf.reduce_mean(tf.square(gradients_l2 - 1.0))
        disc_loss += 50 * gradient_penalty  # lambda_gp is the gradient penalty weight

        # Filter and Reward Valid SMILES
        valid_indices = tf.map_fn(reward_valid_smiles, generated_images, dtype=tf.int64)
        invalid_indices = tf.map_fn(penalize_invalid_smiles, generated_images, dtype=tf.int64)

        # Calculate the average reward for valid SMILES
        average_reward = tf.reduce_mean(valid_indices)
        average_penalty = tf.reduce_mean(invalid_indices)

        # Add the reward to the generator loss
        gen_loss += tf.cast(average_reward, dtype=tf.float32) + tf.cast(average_penalty, dtype=tf.float32)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
import os

checkpoint_dir = './gan_d2_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
cb2_embeddings.shape, len(cb2_embeddings)
# Out:
# (TensorShape([7252, 128, 32, 1]), 7252)

# %% [markdown]
# ## Transformer

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

def create_masks(inp, tar):
  # Encoder padding mask
  enc_padding_mask = create_padding_mask(inp)
  
  # Used in the 2nd attention block in the decoder.
  # This padding mask is used to mask the encoder outputs.
  dec_padding_mask = create_padding_mask(inp)
  
  # Used in the 1st attention block in the decoder.
  # It is used to pad and mask future tokens in the input received by 
  # the decoder.
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  
  return enc_padding_mask, combined_mask, dec_padding_mask

def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, 
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff, 
                           input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training, enc_padding_mask, 
           look_ahead_mask, dec_padding_mask):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
num_layers = 4
d_model = 32
dff = 512
num_heads = 8

input_vocab_size = 510
target_vocab_size = 510
dropout_rate = 0.2

class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.legacy.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size, 
                          pe_input=input_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %% [markdown]
# ## SMILES Generation + Validity

# %%
from tokenizer import SmilesTokenizer
tokenizer = SmilesTokenizer("./data/vocab.txt")

def gen_smiles(generator, transformer):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = generator(tf.random.normal([1, 100]), training=False)
    enc_output = tf.squeeze(enc_output, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    return smiles[:smiles.find('[SEP]')]

# %%
from rdkit import Chem
from tokenizer import SmilesTokenizer

tokenizer = SmilesTokenizer("./data/vocab.txt")

def gen_smiles(generator, transformer):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = generator(tf.random.normal([1, 100]), training=False)
    enc_output = tf.squeeze(enc_output, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    return smiles[:smiles.find('[SEP]')]
    
def is_valid_smiles(smiles):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = tf.squeeze(smiles, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    smiles = smiles[:smiles.find('[SEP]')]

    x = Chem.MolFromSmiles(smiles)
    if x is None or smiles == '':
        return 0
    print("valid SMILES generated", smiles)
    return 1

def is_not_valid_smiles(smiles):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = tf.squeeze(smiles, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    smiles = smiles[:smiles.find('[SEP]')]

    x = Chem.MolFromSmiles(smiles)
    if x is None:
        return -1
    return 0

# %% [markdown]
# ## Training

# %%
import time
batch_size = 8

def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for i in range(batch_size, len(dataset), batch_size):
      input = dataset[i-batch_size : i]
      train_step(input)

    if (epoch + 1) % 15 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)
      print('saved checkpoint')

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))
    
    noise = tf.random.normal([1, 100])
    generated_image = generator(noise, training=False)
    decision = discriminator(generated_image)
    print(decision.numpy()[0][0], gen_smiles(generator, transformer), '\n' )

# %%
import contextlib
from rdkit import RDLogger

@contextlib.contextmanager
def suppress_rdkit_warnings():
    RDLogger.DisableLog('rdApp.error')

    try:
        yield
    finally:
        RDLogger.EnableLog('rdApp.error')

# with suppress_rdkit_warnings():
#     train(cb2_embeddings, 500)

# %%
checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# './gan_checkpoints/ckpt-6'

# %% [markdown]
# ## Transformer Model

# %% [markdown]
# #### Model Building

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

def create_masks(inp, tar):
  # Encoder padding mask
  enc_padding_mask = create_padding_mask(inp)
  
  # Used in the 2nd attention block in the decoder.
  # This padding mask is used to mask the encoder outputs.
  dec_padding_mask = create_padding_mask(inp)
  
  # Used in the 1st attention block in the decoder.
  # It is used to pad and mask future tokens in the input received by 
  # the decoder.
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  
  return enc_padding_mask, combined_mask, dec_padding_mask

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, 
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()

    self.encoder = Encoder(num_layers, d_model, num_heads, dff, 
                           input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training, enc_padding_mask, 
           look_ahead_mask, dec_padding_mask):

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
num_layers = 4
d_model = 32
dff = 512
num_heads = 8

input_vocab_size = 510
target_vocab_size = 510
dropout_rate = 0.2

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.legacy.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size, 
                          pe_input=input_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')

# %% [markdown]
# #### Generate SMILES

# %%
from tokenizer import SmilesTokenizer
tokenizer = SmilesTokenizer("./data/vocab.txt")

def gen_smiles(generator, transformer):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = generator(tf.random.normal([1, 100]), training=False)
    enc_output = tf.squeeze(enc_output, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    return smiles[:smiles.find('[SEP]')]

# %%
smiles = []
for _ in range(1000):
    smiles.append( gen_smiles(generator, transformer) )
print("done")

# %%
from rdkit import Chem

def is_valid_smiles(smiles):
    smiles_str = smiles.decode('utf-8')  # Convert from byte string to Python string
    x = Chem.MolFromSmiles(smiles_str)
    if x is None:
        return 0
    return 1

# valids = 0
# for smile in smiles:
#     if is_valid_smiles(smile):
#         valids += 1

# %%
valids

# %% [markdown]
# ## Generation

# %%
from rdkit import Chem
from tokenizer import SmilesTokenizer

tokenizer = SmilesTokenizer("./data/vocab.txt")

def gen_smiles(generator, transformer):
    input_sequence = np.random.randint(0, 60, size=(1, 128))
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(input_sequence, input_sequence)
    enc_output = generator(tf.random.normal([1, 100]), training=False)
    enc_output = tf.squeeze(enc_output, axis=-1)
    decoder_output, _ = transformer.decoder(input_sequence, enc_output, False, combined_mask, dec_padding_mask)
    final_output = transformer.final_layer(decoder_output)

    smiles = []
    for row in final_output[0]:
        smiles.append(np.argmax(row))

    smiles = tokenizer.decode(smiles).replace(' ', '')
    print(smiles[:smiles.find('[SEP]')])

    x = Chem.MolFromSmiles(smiles, sanitize=False)
    if x is None or smiles == '':
        return (smiles[:smiles.find('[SEP]')], 0)
        
    x = Chem.MolFromSmiles(smiles)
    if x is None:
        return (smiles[:smiles.find('[SEP]')], 2)

    return (smiles[:smiles.find('[SEP]')], 1)

# %%
total_gen = 1000
valid_gen = 0
valid_smi = []
grammar_gen = 0
grammar_smi = []

with suppress_rdkit_warnings():
    i = 0
    while len(valid_smi) == 0:
        smi, v = gen_smiles(generator, transformer)
        
        if v == 1:
            print(smi, 1)
            valid_gen += 1
            valid_smi.append(smi)
        elif v == 2:
            print(smi, 2)
            grammar_gen += 1
            grammar_smi.append(smi)

        if i+1 % 100 == 0:
            print(f"{i} smiles generated")

        i += 1

print(f"{i} smiles were needed to produce 1 valid smiles")
# Out:
# (CCC(ClClCCCSCCC(ss[nH]s[nH]s[nH]Sn[nH]5CccccccccccCcC[C@H]=(==
# (((=NNNNNCNN(()(ClCl)ClnO4cnc4[nH]cccc)cccc3cccccCcc=N[O-]
# CcClClOSSSCCCCSSC(c[C@@H]css5s\ccccccccccccc==())=)=(
# =(cccccccSCCSSSOs\Ss==sccccc)cCccc3c)c(O1)1(1OO
# C(CC(3)=4CCCCCCssssCs)5ccn)cnccccccc)c33c)=cc
# ClCCCCCNOCl(CC(((ClCl)cccc(c(ccccccccccccccccOc=OcO
# =(==C===(C====c))c[C@@H]cc45cn)ccnccc)cccccc[C@H]=)cc11
# 2c=((ccccc(((\ClClSSSScc=)ccc)cccccc3cc(OOC===)1O
# [C@@H]CCNCC[C@H])O[C@@H][C@@H][C@@H][C@@H][C@@H]s[C@@H]Ssss[C@@H]s)scccCcccccCcc[C@@H][C@@H]==((OC=
# c(CC((CC=scNcccCcccccccccc4ccccccccCccccOcc==()(OOC((OOO
# =OOcccccccOc[nH]csC[C@@H][C@@H]Oss[C@@H]sS)cCl))cccccccc=(===1==
# ccnnnnccccccncnnClcncnnnnnnnncOcc)cccccccc1c
# (1CCccCccnnncC[nH]csss[C@@H]ssSCSscc)ccCc5cc[C@H][C@H][C@H][C@H]=(===(==OO
# 1nClCCCC==CCCSCSS[C@@H][C@@H]s[C@@H]SSSSSSScClClcccccccccc)cO=(O
# O1cC(((((CCCCcccccncnnnncClccccccccc3cccc=()1OOO1O1OOOOOOO)
# cC(((((((((((((()ssnccnnccccnc3ccccc3c3[I-]ccccCn)nBr1
# =C)CCCC((CCCccncnn)ncOnncn(cccccccccccccccccc)))c
# ClClClClCl(-Cl(ClcClscccccnncnnnnnccc[I-]cccccccccn)Oc=O3=OO)=)OO
# Cl3cOC((ClSCc=CCnnsnnn[nH]ncccc4cccc)ccccccccCCc13)O
# 1cCcCccc(cc((ClClClScS(n)Clcnn443cc)cc3c)ccc))ClcccC
# 21SCCC((cNsCNN((Clc=sClCCn)Cc4[I-]cccc3)33cc=)O=cc)c
# Cl\ClClClcSC=CSC\\\=ClSS[nH]C44ncn)ccccccc)Cccc3cc)ccO)(=n
# (ccCC(((cccccccCcc=[C@H][C@H]cccccccClcc\cccc)(C(cCCCO(C=C)CO))O=
# C[C@@H][C@@H]C[C@@H][C@@H]C[C@@H][C@@H](\\\\SSSS)Sc=ccc[I-]ccccc)ccccccc=======11
# 12cCC(((Cl((C((((ClClCl[nH]([nH]c)cccccc)cccccccc((=cc(=O=
# =cc((ccc(cccc(333\nnOnc)ncccccc)ccccccc)c=O
# 1((CCC((((((((S\S)SsccN(C\ssc((cccccccCc((=)=OO
# SccCnnSCCC=(CNcC(Sccco[C@@H][C@@H]c55[C@@H]ccC)[I-]CClcc)cccccccccccc(ccBrSBrClBrS1
# 1CCNO(c(C(((ClcSOClO)ClClnClCc4ccccccc[I-]cccccc)1==OOOOOO
# c((((((SC(ClSc(cccnncn4nncncc3c3333333cOc))OCCnOcn
# cC(ClClClcONClClc(cClcccSc\c))\ccccc[I-]cccccccc=)=3CC=2OO)OOn2O
# n[nH]=NCCooNssss[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]55ccccccccccccc))c[C@@H]c)11
# ===OClSCCClClClClClClClClClS\)[nH][nH]4[nH]cc)cccccccccccc)OO=)=c1
# (((((((((((ccc(cccccc)cccccccccccc33cc==3c1OO
# C=C(C(ClClClC=CSCCSSClSSScccccccClccccccccc=cc=O===)=OOOOOOOOOO
# C(C((NC(((((C(cSCcccnncno)Cl4ccc)cc)cC)cc3cccc3)CC)CO
# n1NOO(11ONnnOClcnnncOnOcOOOOcccccc3ccc=cc)[C@H]cN
# cc)(c(cccccoo)[C@@H][C@@H][C@@H][C@@H]s5cC)5ccCcccccCcc)ccccccccc()(c))(((
# s1cCcCcCCNCCCl=CCCCss=sCCCCCccc4)4)ccc=c[C@H]==(==)
# NNNNNNNNNN=NC))OOcOOOOnnnOnCnnnClc[I-])ccccc)cccc=(==
# 1CCC(CCC(SCC(((\\([nH][nH]([nH]cc)ccccccccc)ccccccO)OO)OO2OOOO)O2
# c)cncc=cccc[nH]sosss[C@@H]ccn5[C@@H][C@@H][C@@H]5c5ccccccccc[N-]cc)ccc32c=O))1)11
# s[nH]C=((c(SCC(ss[C@H]Sssss[C@@H]ss5)s5ClcccccccCC)CCCC=C)(1=S
# ==2[C@@H][C@@H]2\(cN[C@][C@@H]\cc)3)cnc)ccccccccccccccccCc=====n(OOOO=
# 11CCCCCCCCNsN=Cc)ccccnClccnc)cccccnccc33cc3=5C)OOO)=OOO
# 33s[C@@H](cccCccNCcClcc[nH]cccc)ccccccccccccccccc=c1=1
# (1CnCnCnNc=s[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H])[C@@H]5c55cccClccccC)ccccccc)ccc=
# (CC(CCC((C([C@@H][C@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]6\[C@@H]Oc(O5)\cccc)ccc)(((3c)ccccS(Cl1[O-]
# ((n(n()(c)([C@@H])[C@@H])[C@@H]\S[C@@H][C@@H][C@@H][C@@H][C@@H]cc)c(cccc(cccccccc)cCCnn(
# OBrcc11CcCCccOClClClcc[nH]O3nnncc)cCc)3))c3cncCO(ccccC))Cn
# (cccN1NcN=NCCSSOSCSS\ClCl[C@@H]\ClCl\55)Clcccc4c3333)3[C@H])c1Oc11
# 22[C@@H]N((CCsCCCCNcClClClC[nH]Clccccc3ccccc5cccCcccCcccCCOO3
# =NNNNNNNNNN[nH]CCn[nH][nH]oooOnOo555cccccClcOcccc33((3cc))1cc1
# snnssCssSSSsssSClsssssSsSCnCccc)CC5cccCcC[C@H]CCC====1
# (=OS)(cC(ccsC\ClClClCs[nH]SnSn1nnccccccccc33ccBrCBrc1BrOOOO)
# (CCCCC((((NCCNNsss[C@@H]cccccc)Clc)c)Ccc)ccC)cccccc((((
# c(CCCCCCCCCC==CCOS=sss[C@@H]CsccScCcCClC)c)cc=OCCOCCs
# Cl[C@@H]3-(((C(Cl[C@@H]cCl)[C@@H][C@@H][C@@H])s[C@@H]=s[C@@]scN\cccc)ccc)))cccCO[C@@H])C1()
# 3c(((((n=()cccSs[nH][nH]CCcccc5ccc)cccccc3=)(===Cc=[C@H]
# =CNCN(c((((((ClCl(Clc\\(c\\cccccccccc(c(c===c=)=n
# 22CO((ClcO()(ClClClClSClClCl[nH]ccnnnncccccccC3=c)ccccCcCCC))O
# CC1CnCCCCCcCCnsCOcc)ccOcnnnncO(ccccc((Sccc(Ccc=(()[C@H])())=)[O-][O-]
# n(OOcnnnnCCCnCOOOOOOcnn6C55()ClccCcccccCc)cc))cccc
# ((((((cCCCCCcCNccn[nH]cccCl4)ccccClcccc4c)c=55c3cc3)
# c2C(n(c(((SsCCCC(ClssSsos[nH]cc)Clccccccc(C3[C@@H]cC=(c=
# =(ClC====CC(SSSSScc\cccccccccc(ccccCc)ccc==111O11O)=O)OO
# (1(CC(((((Cl((Cl(ClClClCl()cc((Cc3(c[I-]cccc))ccccc3=()=)osC
# nCC((((OC(C[nH]ncCClClClCl5C(c(55Clc5Clcccccccc)cc))cCc1))Sc=[O-]c1S11Br1
# 1CCCCCC(n(nCCsnnn[nH]s[nH]cc[nH]C[nH]ccccccccccC(cSCcc[C@@H]((=(=
# ===[C@@H]NNcO(c-OCCl((\Cl)4cnccccccc)ccc=c[I-]c[I-])ccccCOCCOO
# #cc(cccc(()((ClClSSss)cSc)ccc)[I-]cccccccc3=c3cC=)=))c=CcOCOO1
# cCcccccc[C@@H][C@@H]csc1sSCsCCC5[C@@H]cCCCcccc)Clccccc)c[C@@H])CccO[C@@H])(C([C@H]O
# nCl=ClClcScScCccC==c(c\cccccnCccc3ccccccncc)=)====
# CCC(CN(CCNCs[C@@H][C@@H][C@@H][C@@H][C@@H]C[C@@H])[C@@H]Cc5)ccccccccc5c==C==)=)c)[C@H]1
# cc[nH]=[nH]c[nH][C@@H]\SCO[nH]SsSSssSsS[nH]SS\\ccccc)3Cc)cC33[C@@H]2[C@H][C@H][C@H]=O
# ccn(nc(CCCCCSSSs[C@@H]sS[nH]Nss)cccccClcccccccccCC)CC)CC
# ccc(cc(cC((cClClc(SCS)cC[nH]ccc)ccc)cccccccccccO=c)cC
# nnnncCOCCOOOOoo[nH])[nH][nH]n)nnn)Ccccc)cccccc)ccc=====(===(=
# (CCCC(C\SSSSCc[C@H]c=Cc)cccccccccccccccccC===C)OO
# ClSSCCl(ClClCl((ClClCl(ClClSClcccncn)cccccCccc)cC3CC==)CC==
# =C1cCCClSCCcClSSSSSCl\SS[nH]S\cS\\ccc)4CccccccCccCC=
# (((1[C@@H]C\CCCC==ccOClcnnc)nnnncc))33Cl3cc3c)c3cccccc(O
# 1CCC=C==C=CCC=CCC==Cssssscscccccc4ClcccCCCC(sNCC
# OcC=====(ClClc(\\\ClClS[nH]Sn)ncncnccccccccc)ccccC===OOOO(O))
# C[C@@H][C@@H][C@@H][C@@H]sOs=CCCOOsS[nH])[nH])[nH]nnnc4)ccccccCccccccO===c=OOO
# [C@@H]([C@@H][C@@H]((csC(sscc)SSscS\C\\)c5ccc(ccc33cccc))3(33O))()
# ([O-]c1C[C@@H]Clc[C@@H][C@@H]Cl[C@@H][C@@H]cc[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]ccCcc3\c4ccccccc)cCCCCC(
# C=Cl=CCC(cClCl(SSO\s\c)cccc)cCccccccccccc(=))=(==OO
# Cl[C@@H]2c\s[C@@H]s[C@H]CNSCCs[C@@H]SsccccS)sS)\4cccccccc3c=c()O))ccC
# nn(((((c(((c))Ss[C@@H][C@@H][C@@H]C[C@@H][C@@H][C@@H]\cCCc5c5cccccCcC)=====1=
# nCl11ClcnnncCCn[nH]SO)OCOOcOOOOnnC55C55cc)ccc)c3))(((C(
# c(==cCc(cCcClC(cc)c[C@@H][C@@H][C@@H]cS)cc=ccccccccCccccOC)C=1CCCO
# CCnnc1=Cs=ssccccc=ccOc)c)nOCl)ClCCl3ccc)CccccccO)OOO(OOO
# CC(CCCs(cN(N(((c(ccc)c)cccncccccCncccCccOcccccc1
# (C((nCCCCClCC[nH]ssCsClcCSccsc[C@@H]c5ccccccc33cc[C@@H]=))[C@H]O[C@H]
# Ccc=C(c(cccccClccccc[C@@H][C@@H]c[C@@H]ccClcClccccClcccCC(CC)C((C((OOO
# cc(ccccc(c(c(cco=OOoC[C@@H][C@@H][C@@H]ccCccccccccccccccs==111
# 11C#sCC====C=/=ccs==cc)c)c)cccccc4ccccccccCCcC=c
# ScC[C@@H]S=(C\(\\\\SSSClSOsSS#ClSCl)scncc[I-]cccnccccccccccO
# c((((Cc((((cc=ClClClSncnnnccc)c4ccccccc)c)c=OOOO)O
# ((SC==N(CClClClClCl\ClCl=5c[nH]Cc)cc[I-]cc[I-])cccccClccc)=)==SCC==C))OO
# Cl((((1((((((\()o(sSS())[nH][nH]4\4)cc)c333333)Oc)CcCO
# (2(c)(((((ccNcC(ccccc)ccClc)cccc[I-]ccccccccc(=O((O)O)
# ccn1ccccClc)SCs[C@@H]cs[C@@H])[C@@H]c555ClClcccccccccCc[C@@H]c[C@@H][C@@H][C@@H](([C@@H][N+](=
# n[C@@H][C@@H]cccscccs([C@@H]4[C@@H][C@@H][C@@H][C@@H]SsCcCCCCccCC)ccccc[C@@H]C[C@@H][C@@H][C@H](CCCCCCCC
# CS[C@@H]\ClClClC(ClClSClsCClccC=cccCcccCcccCcccccccccOc(=)O(O
# cCc==CCC(CC(ClClClCCSS\)[nH]=Sccc[I-])ccc)c)3cccnc((O(()
# OOC1-cc((((SCcSSOClS[nH][nH]nC)5Cncn4c3c33==c=1O)O
# ((((((c((c((Cl(Clc(cccc)c)ccccc(ccc3)33cccScc=cOncc)1
# CCC1CC((Cl(Cl(ClClCl4Ssc/)cccccccccccccncc3=C3C=CCc
# (C(S(SS(SSSssss)sO)))oo)co54)ccc43Clccc3cc=(=====(O
# =cc1cccccClnccoo)[C@@H][C@@H])ssss[C@@H])ccccc5cc53cccc=c===
# ==\=((((=C(Clcccc)c)cccScClSc)cccc3)ccccc()(==(O
# ((1(1c1((cSCNCC(SC55C54S))cc)ccc)cc)cccc(c(===(
# ===((((((SCSCSSSSSScccc)ccccccccccccccc=c==BrC(Br
# ==(cc(1ccSccc[C@H][C@H]([C@@H]c[C@@H][C@@H][C@@H][C@@H][C@@H]cccCccccccccccCc=cc=(==(=(
# CCC2(Cl(SCcCCCC===n=cncnn44ccccCccc33=3c=O)=)1)c
# ClClcSCCSCSCCCcCClS\S\)ClcSn)nCl5ccClcClc=cccc(=====)OO)OO)O
# CS1CCCOC1
# CCC=SCCccC(SSCCSsSscCs\\[C@@H]Clc5ClccccccCCccCC====c
# Clcc==CClCcc((Cl[nH]C([C@@H]4\[C@@H][C@@H]\s[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]cccCcccccC===CCC=
# 1NN(((((SCN(ClCl\c(C[nH]Sn(cc))cClccc)c)cccccc3cc(cc
# C2)=(CSCCCs(CCOsssss[C@@H]ss5)[nH]nc)Clccccccccnc===[C@H]c1=
#
# (((((cClcccccc(c\ccc=ccccc[I-]cccccccccc))ccCc=)3c(
# ClC==(=C(CC=CCCO(cCcCccC\5\ccccc)ccCcccccc=CC)C3)(OO(O
# SOnnC=(C[C@@H](((ClSCCClCS==ClC)SCSccccScccccccCC)==C)
# CCCCCC(CcCCClClClClCCClClClc[nH]cCc)cccClccccc3c=(==OO((OO
# ccccn(((cccc)cc)CS\\)c)cccccccccccCl3=3cc)(=))1OO
# nncc(c(ccc(SScSCs=5SS=C[C@@H]cc55ccccc=3===)=)==)(CC
# ClCl(((cSCNCCC[C@H]ss\s[C@@H]ssOScS)cccccccccccccccOc[C@@H]((((
# C=1C1C)nn)nn)cCCC[C@@H]=cCCCcCC[C@@H]ccccc[C@H]cccc))c(3)(O)=2(c
# ScCC11C1=CCCCCSsCsS=CCSCCCCccccCccccCcccc=2)[C@H]C(=(
# CC1(CC((cC[C@@H]\s[C@@H]CSC[C@@H]CCC[C@@H][C@@H]c)CCC)c4ccccc)ccccCC(CCCCC
# Cl===((\CCSCcccClSScnCCn)nClccc)cccccccccccOcO(ccc(OCBrBrO
# [C@@H][C@@H])ss([C@@H]Sssss[C@@H](ss[C@@H]ss[C@@H][C@@H][C@@H]s[C@@H]sccccccCcccc(ccccc==
# CCC2(ClCl)ClCl)Cl(ClClCl(S[nH]()ccc)cccccccc)cccc)cc[C@@H])===
# OBr1CCS=====C======ClOClS)[nH]CCcccCccccc)cccc=c==c
# =((C2([C@@H]SCCCCc[C@@H]ccscccccc)c)(cc)cccc)ccc(cc)((cc
# =(((C((((Cl[C@@H]c([C@@H]s[C@@H]=sss5sC5sscc)ccccccc)c[C@H]c=====
# cc5cScccccc1cc)[C@@H][C@@H][C@@H][C@@H][C@@H]ccClc[C@@H]cc[C@@]ccc4cccc)())((cCOOn
# COOCCCCCC=OC))N44sOc[nH]ss4osClcClc=cClcClc)ccCccccS(c())N1=[O-][O-])11
# =c(CccccccSSccSSSSScc\ccOc3cccccc3ccCCc(CSCCCC
# 2([C@@H](((CCOClccClc3cccc)c)cccCcccccccccncccC[C@H](=O)===O
# 1111(11C\\cnn1(nnnnnnncnClnClnncccccccccccc)c)[C@H]ccSc)c
# =(Ccc(c(cccccC=O\\[nH]c[nH]cccCccccccccccccccccccc()OOOOc
# ccccccClcc1cssc[C@@H]sc[C@@H]cs=ccsccCCccccc)ccc)c====(1(1=)
# 11cCC(sC(cs5s(s[C@@H][C@@H][C@@H][C@@H]s[C@@H]sss5ccccccccccCcc3C[C@@H])[C@H]CC[C@H])
# ClClClClClClCClcClSSSClCl))ClClCl)C)cCccccccccccc)ccc3ccO(O=
# C===((-((((((((ClcCl\[nH]csnncCnClcCl)ccn)ccOcOc)c))C)O)
# (11c)c((ccccCccccscccccCcccccccccccc)c=(c)[C@H]([C@H])=(12[C@H]))(211
# c(ccCCnCCC((Csssss[C@@H]ssss))sccClc))c3[C@@H]3=(==OO=1==
# cccc(((()cc()ccSCl(SSSCcCc5)cccClcccccc=cccccCCO===
# (((ncSCC(Ccscc(ccccClcccccccc(cccccClcccccc=)Br=)
# ==(((((((((\s([nH]ccCl)[nH]scccC)cccc)ccccccccO)=)=OO(OOO(22))O
# 2((2)(c(((Cl(ClClSClClnnccnCnn#ccc4ccccccCccC===))=
# 2((CCCCCSCCCCSCccOcccCClc)ccccCcccccc)[C@@H])C
# cC1)cnncccncc[nH][C@@H][C@@H][C@@H][C@@H]5[C@@H][C@@H])[C@@H][C@@H][C@@H]))ccccccccCcC[C@H]c1[C@H])==1
# #==O=(NNN\\=sssscsCs5ccccc4Cccc)[N-]cc)cccc==c)[C@@H]=1)OS((==
# (CC((([C@@H]ccCccC[C@@H]Csss=)5[C@@H]5[C@@H]555[C@@H]cccc(3cc3c[C@@H]CCC=Onn
# CO)CCNNNNNNCN[C@H][C@@H][C@H]s[C@@H]C[C@@H]C[C@@H][C@@H]55C5Cccccc)=cccc3cc)3()
# 1111cnnnnncClcOc)nncOOOOcccccccccc)cccc3Occc3[C@H])c3ccc)[O-][O-][O-][O-][O-]cs)so[O-]Soc)nncc1)1S1111[I-]n111111111c111[I-]111111111111111111[I-]1111111111111
# 2111CCnCCCC[nH]-C[C@@H]s[C@@H][C@@H]C[C@@H][C@@H][C@@H]sCCcc)cc)cccccC[C@@H][C@H]C)C[C@H](C)==
# nC(CC(c((ClClCcOc=cc==s=cc#ccccccccccccCCC=c==O=O(OO
# 2[C@@H][C@@H][C@@H]([C@@H]([C@@H](((cCl)CcCcCccCSscCccccccccc))ccC==c)O((=
# ((((((((((S=(C=(OOOn)ncccc))cccccccc3ccc(==c====
# O=CCC[C@@H]((((ClClSSS)(cCC[nH]nc)4n4Clcccccc33cccCC)OOO
# 11([C@H]1SCCCsCCCS[C@@H]CC[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]C))[C@@H]ClccccccCC(CcC(CCC==
# O(C((((C(c(c\(cccsccccCcCccccccc3ccc3c3cCc)cc=BrCn
# Cl==cC=NCCcClClCClClClCCClClOCl\[nH]nnnccccCcccc3cc)33CO)OO
# C(((((((SC(ClClClClClClSSccccccccccccccccccOcc=OOO[O-]OO
# Cl\CClClC=SSn(cSClS=Cl)cccSccc\[I-]ccccccccn(Cccc(c(=
# 1CCCNNNNNNNNNNNNoOnnnClCC5c((COc5ccccNc3c33)3)(((O(=((((((
# ([C@@H]((sCNNC(=(OCOO(OOOO)OOCnCCSccnClccc33ccc[C@H])=)=
# Cccncccccc(ccc)sssc)ssssscccccc)5c(ccCCCC(=cC
# S1C1====SSSC\ClSScccccccccccccccccC))cccc3C[C@H]c[C@H])=1
# ClClCC=Ccc(Cl\=sCccc[nH])cncCcncc)[I-][I-]cccccccccCcCCCOOO)OOO
# 2[C@@H]=)(-(cCl(ClClClScc[nH][nH])[nH][nH][nH]c=cccccc)ccccc))ccOc[C@@H]([C@H]
# SS1C1cClClClCSCCcscccccCcScccc3ccc[I-]c[I-]5)c3=3=)2)=Oc=n
# =(=(((((((cClCc(cSCCCcCccnCcccccCccC3cc==)OOCCCC
# ClClCl(Cl=ClOClClSClClClClSCl)[nH]4cn4)c)ccccccccccccc1OO)
# =O--cc-ccOClCl(Cl(ccClcc)cCcccccCccc)cccc)Ccccccc((OCn
# CCCCCNC(((OCl(Ccc[C@H]c)cS[C@@H]c(cccccccccccccccc====)1(OOO
# cccnCccSn[C@@H]s[C@@H]s[C@@H]OsSs[C@@H])[C@@H]ssss)CcccccCc)cccc=c3)2[C@H]O(
# c=(cClcccccCClcClClc====###ccccccccClccccC3ccc(C)=)=
# Occc((c(((((ClClClClClSSCnC[nH]ccnncccccccCc3cc3)nn=COO
# CC(CClClClCCClClClSCSClClccc)ccccccccCCcccc))cc(======
# ClClCC(SCCCClCClClClClcClClnnnnc))ncccCcccc33cccccccOccOCCCO
# 1CCCNNN=OOO=SCCSnCSCCOOCCClClcccccccc)ccccccc)cc===c==
# =cCcc(-c-ccccClCl(S=[nH]CScCcScccccCcccccccc3[N-]Ccc)=))
# 1C=O=N(cc((((cc((Cln\Closnscccccccc3Cl33ccOc)cOcc)cc
# 2(()c(Cc(((cCnCc(CClCCCCCn)ccc)cccccccNc3c))c1))(O)C)
# CC2=CCCCCCCClOClClSCn1)O[nH]4nnnnccccc35cOccCccCcc)c)C1
# cClccClccCcccc[nH]S[C@H]OC[C@@H][C@@H][C@@H][C@@H][C@@H]ss[C@@H][C@@H][C@@H]\c\cClc(cccc)[C@H]====CCCCCCC
# =CCC(nSC(CC[nH]CCSCs[C@@H][C@@H]\[C@@H][C@@H][C@@H]\S[C@@H]\[C@@H])Clccc334ccc=1c=1==
# c[C@@H]c[C@@H])([C@@H][C@@H]cccOccc[C@@H]Cc)cc)cccccccccccc4cccc=C)CCC==
# =(((((((c(Cs(((\cncccCcccc)cc[I-]cc))c)nc3cccc)cc(=
# Ccccn((cC(ClSCSCS[nH]()cccc)c()cCcccClcc3cc=)c)C=)c3==O)C3=))
# C==cccFncc(cClcc(c4c[nH]5[nH]5cccccccccccccc=3CC==OOO=OC=OOOOOO
# =nnCccCcccs[C@@H]s[C@@H][C@@H][C@@H][C@@H]cs[C@@H][C@@H][C@@H][C@@H]cSS[C@@H]cccccccsccc
# #CCcCcccccSC(CccCSccCc[C@@H]ccccc4cccccccccc=)OOC(=)))C)(
# O=C2((((scNcNc(cccn4nncCCcccccc3c3==cc)c1cc1
# =======CCC(ClClClClClOClcCn)ClcCClcccCc))ccccC3CCO)OOOOO
# OC111c(((\(((SC=\SSsC[nH]n)nnCn)cccnc3cc333)O=)=C3OnOCO)OOO
# nnCCCCNCCNCCOCs)[C@@H])sOcOc)cccccccc3ccccc=Oc[C@H]c3c=CC
# ((((c(((((ccClScClcc4ccccccc))4ccc3cc3cc)ccOc1)OOOC
# 1cc(c((cCCCCCCSSNNssc[C@@H]Osscc\)ccccClcccccc=cS[C@H](==(==
# C)1CC)CCCCOCC(CCCnnCnnOCC(CCCCCc=CScccccccccccccc[C@H]CCO)111111111111O11111111O111111
# (cccccccccccccc4cSccccccccccccccccccS)c)cc3===
# BrC==#nCCCCCCCs=#C#C=#cnScCC)Cccccccccccccc(ccSc(=
# 2CCCCCC(cClClCClSCC=CCl[nH]snnc4c)c5cccccccccc))33)==OOO))OO
# 1cClCcc(((cncs[C@@H][C@@H]sssSSs[C@H]cscCcccccccccc=C===)=
# =(=(((((C(((ccc[C@@H][O-][C@@H][C@@H][C@@H][C@@H]\cNs[C@@H]scccccccccCc3c)==OOO1
# ClCCClClClCl(Cl(Cl()O)ClClCl[nH]nnnnn4cncccccc3cccc1)(1OBrOOO
# cccs==COCCc(ClClCCl\\\\ClSnnCnccc4c5)cc)3c)=c===
# CC[C@@H]((cCCcCCCCOCO[C@@H]=C[C@@H][C@@H][C@@H]s[C@@H]s[C@@H]cccccccccccccccC[C@H]===)=
# C=C(Cl(Cl(Cl((cClSCClClClC[nH]n)cOnnccc)cccc3333C[C@H]==((=OO=
# C=CC(-ccCc[C@@H]\c[C@@H][C@@H]SS=sssccccccc[I-])ccc)ccccc3CCcc==C(
# C[C@@H]CCC(SCcCSCCCcClClcOc)cccccccccccccccccccccOccc1
# 1n1cccccccssS=Cs[C@@H]s\[C@@H][C@@H]s\\55ClClcClcccc=cc3C[C@H])[C@H]C[C@H]
# C1CSS=(S==c\\Ss\S==SS\\ccccCCcccccc)cc=[C@H]O=)1==O=OOOOO
# (nn(cCCCCCcCCCCOOOSScsClClClS()Clc)c)ccccc[C@@H][C@H]==1c1
# (n(nn((cccc(([C@@H]cS[C@@H]s[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]s5ccc)cCcccc)c(===O
# [nH]222(occnnnncnsC4SSNCs[C@@H]sSCs=cc)5[I-]5ccccccccc22Ic==))[C@H])
# =(-c(c(c((ccc(cCcCCccc)cccccccccCcccc3)ccO3(c===(
# CNNNNNNNOcNcccscccccs=nnccnc)c)cc[I-]ccc3c3cc3O)
# =c((cCCCcccc\\S[nH]SSS[nH]CClccc)ccccccccccccc==1==CCO
# ccnn((((((c[C@@H][C@@H][C@@H]S[C@H][C@H][C@H][C@@H]Sss[N-]sssc[N-]ccccCccccccCCCc3CC
# CCCC(CCc(cccc\()ClScn(cccccccCClcccccc5Oc=)===))(((=
# ClC=cOClClClClClClClClClCl(cnnn)nnnClncc4ccccc)34c3))====(=O
# ccCcccc(1c[nH]cc1cc\cccccccccccccccccccc[C@H]c))cS)=c111(11=)=[O-])2O
# SSOSs[C@H]SSSS[C@H]=[C@H]ssSsss5ss5cCl5ccccccccccccCCC[C@H]===O[C@H]
# C=C=Oc((((((c\==)c[nH][nH]cccccccccccccccCccccccc3C=OOO=12O1OOOOOO
# CCCCCCcccScc(ClClClcnnnC)nnncnccccccCccc))c))cccc
# nnnCCCCCCc(OOOOOOO4OOnnnO6n66cccccccccc[C@H]c[C@H])11((11
# CCCC((SCCCCCcccClClSSncccc44Cccccccc3cc))=c=O1cc11O
# C=NCC((OCCCCCCs)oonon)nn5ncccnccc5c453)cc3cOc3c=(===
# ClC[C@@H]C(ccccc(cc[C@@H]s[C@@H][C@@H][C@@H]CsCssssCl5cClccccccc)3c)C[C@@H]C))(=
# CC((ClSCSSS==CCC(c[C@@H]cc[C@@H]ccs)ccccc5cc)cccc((3=)((C(()
# 222CCC=CC==C==S[nH][nH][nH]ccOcOScccccc)cc)ccc(cc=(cOO
# 11CCCc(((((([C@@H][C@@H]([C@@H][C@@H][C@@H]ccCcc[C@@H]ccc)cccccccc(cc===c(OO)OOOO
# CClClClSCCCClC(Cl(ccSSCCCNc)ccccccc)cc3c3cO3c3c=)=OOOOO
# OCSCS=====C=ClCl(\ClCl[nH][nH]C[nH])Cl)Cl)))44c)c3c33cC3O=)F=Br
# 1CCCc(Clc(ccos[C@@H][C@@H][C@@H]s[C@@H][C@@H][C@@H]sSsssClCl)c5cccccccc())((C)))CCCC(=()OCl
# ==O)cC==CC(CCl(((\\\\)ccCl-cccc))cc3ccO(O)(O))O))
# 1cncnnnc[C@H]Cl(O\s[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]ss)ssccC)ccc3ccc)cc)CC)CC(n
# S#cCCCcCC=[C@@H]C\(=\s[C@@H][C@@H][C@@H][C@@H][C@@H]\[C@@H][C@@H]\C\\\c5cc)5ccc)[C@@H]=CCO2O)
# (C1CCC(CS(C(ClCl((\cccC4nnncccC[I-]4cc3ccccccCCcc3=CC)COCC
# n21cC(n((Oc[nH]Oo)445[nH]=55555c5cccccccccccccc=)==(==
# 222((cCC=cCCscClccnccCCcc[nH]ccccccnccn)ccccCOc=O==)==OO
# ClCl((-((SCcC(SCS[C@@H]C[C@@H]\)[C@@H][C@@H][C@@H]c[C@@H][C@@H]c[C@@H]\c5ccccccOOC)OO(=(O)OOC
# Cl[C@@H][C@@H]N((((\(\ClccScClccccccnccc)c#Ccccc)3333=O)O=)==)
# (((((S(((cCl((cClClClCl1[C@@]cccccccccccccCcccc)CC(CCCC(OO))
# (111(SCC[C@@H][C@@H]C(=c[C@H]\\Ss)Sssscc=ccClcC5cCccccCcCCCOC[C@H]=[C@H]
# (21[C@H]C((((ccCNClC)ClSCl[nH]ccCcccccccc)cCcc)cccc===O)OO
# cccClClc)cCcccCc\SSSS\cC\5(cCccc)cc3c3ccc==cOCOO=
# 1CC(cCCcNNCCCNC(cCl)CClc)ccc)ccc)cccccccccc(===
# ==(SCN(((\==(=ClSOClClCl1nClCl5=Onccccccccccc)ccncc(=(
# CCnCc(((c(((3o\\\Ssss)[nH]scClccccCcccc)ccc==)CO)OOC)
# ClClClClClCC(cClOCClcOnnn)nn)ncncnncnncccccnccccnc)cO
# CCC(SCCC(=ccccSccScSScc(ccccccccccc3====))=On
# (2((CCCC(((Cl(((Cl)Cl44c)\[nH][nH])[I-]c4c)c-ccccc=c3c(C=)=(C==1(O
# sN(NNNNNsCNN[C@H]=ssss[C@@H][C@@H])[C@@H][C@@H]CCC5Cc[I-]5c)cc)c(c[C@H]3)c(()
# Cl=(CC(C(((((\(CccccCcnccccccccccccccccc==O))==
# 21sCCC(CcCCCC=ClSC=))=[nH]CccccccClccccccCccc())))O)=(C)=C))C
# O==c==CC((-Cl((Cl\\\Cl[nH]=c)ClcccClcccCccCCc)c)c3c)ccc2O
# ClClCl(((c(cScnnSnSnnCO[nH]n\[nH]N)NcccccccccccccccOn
# c(((((((((ccsss(ssss5sscsccCccccccccCcc(c[C@H]11=1=
# =((((cCC((cc[C@H]c[C@H][C@@H][C@@H]c[C@@H][C@@H]=s55scccc)cccc)ccccc3=((3))12O
# 1=cCCC====cc-ClCssss[nH]5SsnCcClcClcccccccCccc[C@@H][C@H])(1[C@H])
# Cl=C=CO(CCCl(ClClCl((\SnccCcccccccccccClc5C5)))CCC3()OOnO
# 2NNNNNN[I-]CCssssss)ccccs1c1ClClccccccccccccccOO(==OOOOO)1
# C[C@@H](((Cc((Cl(ClCClClClcClCl\Sc(cccccccnccccccccccO))1C
# C((((((((ClCl(Cl\\sc\C[nH]\[nH])nccccc)ccccccccc=cO)
# CcO==CCCCCClssssss[C@@H][C@@H]S[C@@H]SSSS[C@@H]SSccccc5)cc3ccccC[C@@H]1[C@@H]))
# 11CC[C@H](((CCCCCCs=c===nncccccccccccC[I-])nc)c=c)=(
# S((c(((((([C@@H]c(c(ccccSccccc(c(cccc)cccccc(CC)CcCn2
# cc1)([C@@H]1=cccCsss)[C@@H]CC5C55C5ClC5)C))cccccc==S===1[C@H]=1
# ClCC((([C@@H]cCC((ClcSClClcClCSc\ccc\ccccc)cc3cccc=ccc=
# NNNNNNCNsssss[C@@H]CssOOOOO)cC5CCcn4c3)))cCccc)3[C@H]c
# Cc(((((CcCc(cc(c=[O-]cSsccscCccc)ClcccClClcc)cccC)cc=)=C=s
# ==\ClClClClSOCClSCl(ClClcccccClClCl)ClccccCcc)cccccc=C=))=3)O)OOOO
# nn)nnnnn(ncsos[C@@H])ccccsClc)cccc)cccccc[C@H]c[C@H]c)(Ccc1=C1))1
# SccCC(((Cl(c((c(Sc)c===cccccc)ccccccccccc=O==)=
# ccc(ccc(cS====SS=SSSSc55ClccClccCccc)))ccCc))==1
# 11cccnccSsscCSSS[C@@H][C@@H][C@@H][C@@H][C@@H]c[C@@H])c5cccccc)cc4cc3c)cC(=)===C
# ((C(((([C@@H][C@@H]cccccccccccc)ccc)ccccccccccc3cccccc=)O1C1
# ccc(c((c((cO[C@@H]o\\CC[C@@H][C@@H][C@@H]5[C@@H]5ss5ccc)5cccc(cCCCCCC=====C
# 22(([C@@H]CCC((sCcscNccS===ccc4cSCl4Clcccc[I-]ccCccc))C=O)==
# 111ccc1cccccsCssSCSnSSCCCcc)c)cccccC[C@@H]C[C@@H]C[C@@H][C@@H]====1(=c
# C(\\CNCC(\SCCC[C@H]s[C@@H][C@@H][C@@H][C@@H]ssss)55ccc)cc[C@@H]()[C@@H]())[C@@H](O((
# ccCcccnccSsSC[C@H][C@H]S)SCs[C@H]s5ss6cccccccc)c)3=c())=(
# 1111CC(((cccccCScnnnc5)4)ccnc333333333333cc3OOO)))1On)O
# ((((\\\\\()Nnn)nClnnnnncnnnncncnccccccccc3ccc3cc=c((
# CcCcc((c(((((cc(c)c)ccccccccc)cccccccccccSC(((=)c
# Br1C(((cCCNCl((SC(SSSSSSC=cccc)ccccccccccccCO==)OC=
# =C1CC(([C@@H][C@@H]cc(ClCClClcClClSCCCCcnCClcc)nccc[I-]cc33cc==C==O
# 1c1C(=(C====CSSC=s[C@@H][C@@H][C@@H]c[C@@H]ccccc)cccc)3cccc=c=====OO
# (111((c(ccc((cccScsncccccccccccccc[I-]ccccC))))(=O=OOOOOOOO
# #CCCC((ClCCClClClClS(ccccC\c=cClccCcccccccccc==1OO=2OOO
# CcC(ccc=CCCCcc=OO=O)s=O[nH][nH])ccccccccccccccc)cCC=)CCC
# O1CCCc-CCCCClClClClClClcCcCcccccc3ccccccccC(=C))Cn31
# cCC((cC(CCCCCs[C@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]s=cscNcc)ccccc)c)O)))(nn(
# 2BrC=((\[C@@H]S====S=Sc=c=cc444ccc))ccccccc))(c=)=(=O
# (sC=NN=C==s(c=[nH]sooos)[nH][nH]O[nH]c)ccccc33ccc==(==(c(O
# CCN(NCCCC(NSCcCl(cccCsscscscccccccccccc(c)cc(()cOBrBr
# c(((c(cc(SCCCCClCl====[nH][nH]c))cccccccccn)cc(c))C=O
# ClOS==C=SCS==OCl=S=cNC[nH]C[nH])ccc4c4ccccc=ccc)cccBrBrcn
# NN==ssNCSSSCCNN[C@H]s[C@@H]\ss[C@@H][C@@H]s5c5OOccCccc)ccc[C@H]c[C@H]3cc[C@H]1[C@H]N[O-][O-]111[O-][O-][O-]
# c(=CCClccCClClcssss[nH]sssscccccCccCc33ccccCc(===c(=
# =Cccccc(ccc(SSSCl\\\SS)\\\Cl)Cl)ccccClClcc3cc=(===o==[O-]
# 1nCCCCCCCcCCCCs[C@@H]ss5[C@@H]5[C@@H]5c55555554c33c)3=))=[C@@H]((=))(c
# CC=CC=C=CCCCCCCCNOOOnOOnnOnCOCCCCccccCccccClcc=))))
# CcCCC(c(ccc(cSSClSS\cc[C@@H][C@@H][C@@H]cClcccccccccccCC)ccCcnC(
# ((((CC(CO((so[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H])sClcccCccccccO===(=)O1[C@H]
# C=NNN(Cl(C(ClClClClClClClcSSsSs[nH]C\ccc)ccc)cccccccnccnn(C
# CC((((((((((ClCl)SSCccccccc=ccc)cccccccc(cO(=CCCOOOOOO
# cC[C@@H][C@@H]\(((((()S=scccccccccccccccc)cccccccC=C=
# sClCcCn(ncc[nH][nH][nH]Cls[nH]sss[C@@H]ss)ss=cc)cOccc3)c[C@@H]cC[C@H][C@H]1=NN
# Cl[C@@H](CClClccccccc=Ccccccccccccc3ccccc))3)ccc=cc=c11
# 11ncBrnnccnOccnOnnnnnnnOcncccnccc3c3c333c(N)c(c)O333))1n1)Br1c1)111Br111n)11
# 2((((OCl=NCClClCClS)(Cls)C[C@@H][C@@H][C@@H]CcccccCl)cc)3ccc)C((C()CC((CC
# ClCcc(cC(\.(c(((((Clc4\()ccc3cccc)c3cccccO(CcCcBr(C
# =cCcccccc=ccsssss=ss[nH]555s\Clccccccc3ClCcC(CCCC)CC=CCCC
# CClC(((((((c(cCcClc)c)cCc)cc[I-]ccccccc)nc33cOcccc)
# CnnCnnncccSnScs[C@@H][C@@H])\c\)s\\54cccc(ccccC[C@H][C@@H][C@H]sC==C=
# cc((((c(cc((cccc(O6o4444)4cccccccccccccccccnnO
# #C11C1[C@@H]C11ccC[C@@H])[C@@H]c5c[C@@H]nn55c5ccccccccccccCCcCCCCCCC=3
# 22(2(((((C(ClCl(ClCl)ClSc[nH]nnnnnc)ccccCcccccccc))c3311
# Cc(cccClClClClClClOSClClS[nH]nCl[nH]nCcccccccccccc33c))cccC
# 1ccCcS(cCccs[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]cc[C@@H][C@@H]ccs)c)c))ccccccc[C@@H])[C@@H][C@@H]==o1
# CcC(\c[C@@H](\C\\\[C@@H][C@@H][C@@H][C@@H]cc[C@@H]\c\\ccccccClcccc()cc[N+]O()=((=OOOOOOOOOO
# ccccccc(ccccc(ccS==\ccccccNcc)ccc4ccccc3[C@H]3=OOc3())OO22OO
# ScnSnnncnnCCl==(csc[nH]ccccCcc[C@@H]ccc[C@@H]cccccOccccccccS)c)cccc
# Clc[C@@H]c((((((C[C@@H][C@@H]ss[C@@H]cssssNsN)sccccc)cccnc3=)c)C(C(OO
# CC\SS(SSS=S\SSC\=Cc=cccClClc)ClClc)ccCl)cccc[C@H]ccc)cc)S=C=(==
# 2ccccccc((cccSS\sSnSCcnCcc)ccccccccccccCCC)CCn(
# OOOccc-cccccc[nH]s[C@H]sS([nH]S[nH]nnnccClccccccCccccc=CCcCCC=C=(
# ClClCl2ClSCSCCCCCCClS)nCnnnnCCncncnccccnn333c3c(==(=
# ((\SSSCCCC(\Cl\ClSSSSss[nH][nH])cc)cCl)4c)c)3c3ccOO)=)()O
# n11(()cSCCCCCNcOOccOc4cCccCc5ccccc3c3C3c33==[O-]===)
# 2c21C[C@@H](((sccssccc)cc)ccccccc44c3c33cccccOOOnnnnnC
# c=oc=cccc[C@H]cc[C@H]s[C@H][C@H][O-]s[C@@H][C@@H][C@@H]cscc\cc[C@@H]ccccccccCccCC==CCC(
# n1((nn(nn)nnCl[nH][nH][C@@H][C@@H][C@@H]sss5scccc5cccccccccCCCO==)==
# nccnc(c(cc(SCCss[C@@H]S[C@@H][C@@H][C@@H]SSCs)[C@@H]ccc)cccccccccc=
# n1(1SCCCCCCCCCnnnnnnnOnnC)cncccccccccccc))Nc(Occ=(=
# c=Cc[C@@H]Sc(c=ccc[C@@H][C@@H][C@@H][C@@H]cccccc=c5cccccc-Cc4cccC(===
# )CCCCCCCCCCCCCcnOO(OOO(nnOn(N555ccc333cccccc(Cc
# OCCCC(ccSccCCcccccc)ccClCl5)ccccccc3[I-]cc3)3C=)C=c)O[O-]
# (C1CC=CC(CC(=ClClClSCl\)cc)(cccc4cccccccccc)c==OO)CCOC(
# N((((((SSSC(COnnnnnOnOnnnnnOcccccc)cccccccccc
# (=c[C@@H](S[C@H]CCs[C@H][C@H]ss(cS(cOcc5cccccccccc(c3cc=C=OCCCC=COCOOOOOO
# 2C(CCCsCNCCCCl(c(ccnncnnC))ccc)c4cClcc(Ccc())====
# =(((((((((((cccC(ccccc3cccccccc[I-])cccccc=)=ccc11
# SClClC=CCCCC(SCCCSc==Sccccnncccc4cc[I-]ncc33)[C@H]))))1
# ((((ccs(Cssss\sNs[C@@H]CssSccccccccc5c33c3c)[N-][C@@H][C@H]==11
# 2(C((ClCCl(Cl(((Cl(SSCS[nH][nH][nH]cc)ccc34cc)ccccCccccc=cO(O)
# (((((((=CC)O[nH]sO[C@@H][C@@H][O-][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]csccccccccc(c)[C@H][C@H]====
# 1cn((((c(cOcClsClSssccccsClccC45ccccccCcccC=====C(
# n(CnCCCCNCNCcCCCcn[C@@H][C@@H][C@@H]c[C@@H][C@@H][C@@H]44cc4cc5ccc)Occ))cC((
# CCCcCCCCCCCCCCSC[C@@H]c[C@@H]\[C@@H][C@@H][C@@H][C@@H][C@@H]cccClcccOcccccccc3c(c1
# s)CCnnnSCCSCCSnSSS\SSS\cnnnOccOcccc3[C@H](cc[N-]c(=s2c
# 1O((cncSc(cccClCccCnncn)n)nccccccccccc)c3)==)c
# cnccccnccccNcOc1ccccccClcc)cClccccccccccc[C@H])[C@H])C===)NN
# n1nnC=CCnnClSnnnClClcOClClOOO=OO)Cl)c)c)cc4cc)cccccSSS[O-](11N
# 2CCcN(OCCCCCC(c(c=ccc[nH])ccncccccccccccc(c)==(C()OC)(CO(nC
# #CC1CC(cCClScCSSSSSS=SSS=sClcClccc)Ccccc=Cc)[C@H]C)CC=
# (((CCC[C@H]C(((((ClClccccccccccc)cccccccccc3)3ccc((OOO
# =C=CC(\C(((c\=(\ClCl[nH]S)cs5c4n=5)n)c)3c3c=c[C@H]C)=Oc)[C@H]O(O=OO
# Cl2[C@@H]((((Cl(((ClClCl\(cCccn=nccCccccccccCccccc=)O(==(1OO
# ClC========CClClClClClClCl\43\4=4c3)cccc)cc)cccc(=)=(O=O
# cClCS==ccccSCC(c==c#ccccnCnccccncCc44cc3cCccn)n)ncOnBr
# (((((((((((cC(((ccc(=5#5[nH][nH]c)cc)cCcccccccccC)cccCCCOcc)
# cNC====cOOccOc(cClcc[nH]Cloonccc4)c3c333c3cccc)ccc=Br
# 1cncC((cC(ClCCClClClClScccc55cc)ccccccccccc3O3nn
# (C(C===CCCl[C@H]CC\\ssCCccccccccccccccccc)33C3=(=c=1
# =((CCC((((((\SSS(SScCccccccccccccccccccccBr)nBr))(
# Clc[C@@H](((C((((cN(cClccnc)()nnnccccClccccccccc=ccCC)))OO
# CNNCCCCC)cCCNNssc1s\[C@@H]sccccccccccc)ccc[C@H](([C@H]=[C@H])[C@H])cO
# 1nccn((\c(2Clc)nnnnnnnNcnnn((nc)cnccccc33)33Nc(c)3=((((=[O-]O)[O-]
# 222=CCCCCCClClcC(cClClCl\cn[nH])ncccccccccc3c)))cCC)CCO=OOOOOOO(OOO
# Clc2c(cCCc((c(ClClO\\Cl[nH]C[nH][nH]44cnc4ccccc4c))c))ccc
# nnnOCCncCCCCCNOOOC=ccccccccccc)cc)ccc=1[N+]=O1C1[N+]==c[O-]1
# ==(Cc=((ClCCSCCONCccnCn)cncc)4)cccccc333cc)3cnn
# Br(((((((cO\=\SCSSClClSn)(cClClccccccccCccccCccCCO=O=OOOO
# ClC=O[C@H]CcCOcccc((cnClncccnnnnc)4Clcccccnc3c3cc)Oc)c
# ccc(1c(((ccc[C@@H]c([C@@H]c)cCccccccccccccccClcccc)c=c=))(=)cc1
# 1NNNNNNNSCsCSSSSCS)\cnnnnCnSClcccccScccc(O3(()((((
# NCNCC(CCCCCCC((ccClncnnOnCncnnCcccccccccc()cc()c11[O-]
# =2C((((c[C@@H]cC=[C@H]CCsSCOcC[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]cccClcccc)cccc=C===C((==
# ccccccn(ScccScSS=[C@H]S==s=ccClcccccccCcc[C@@H][C@@H]
# C=c==CC====C=CC=ClcSClcCl)cccccccccc33cccc=(==(==O
# C((((((((((ccCccccccnncc5n[I-]cccccccccccccc)CCC)
# (=(C((((((((((c([nH][nH]nn)nClnnnnnccccccc3c=3))Occ1
# 212c1ccccc(ccccc[C@H][nH]Occc[nH]NcNcNccccccc==55O5)c)c)OCO)cC3)OO
# 1CcCNcnNNNNsNcccO1Occccccccc3)ccc)cc)3cc[N+]======
# cccClnC[C@@H]Cl[C@@H][C@@H]c)cccc[C@H]s=ssnccc)5cc)ccOc)c)ccC[C@H]=(=(O=(==)
# ==C((cN((Cl((cSSccScc)cccccccc)c)c)cccO=(c(cC(C))))C
# ClCCC(2Cl(NN((ClOCl\\c44cccccc5))ncncccccccc)ccnnc
# ccClCCCCCcSNsN[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]sSnn)cncccClClClc=ccc=c===s==
# =(c(((c(((c((c)ss[C@@H][C@H]SsSsssCsccccccccccc)ccn(=cO
# SS1SSC((((((()((((ocnnc))4334n3c33cc3ccccBrBrBrBr1
# 2(((cn(((Cl((Cl(Cl)ClClccn5[nH]ncncccccc43[N-]c)33Oc)))ccCBrBrBr
# C(CN(ClC(C(cCc(ccc[C@@H]cc=c=Ccccccccccccc)cccc==)====)
# c1n(((((ccccSCCCccCScCCCCcccCcC(cccc)cc====(C==(
# 1(((((((((((ClClClccc)n[nH]nn(()cc)ccccCl333333Cc=(==Br
# ClC=cCCCS=ccccC\S\\\\)\S\\))cC)cccccccccccCCCC)c
# c1Cccccccc-((-(4c[nH]Cc55c)(ccccccccccc3([C@H][C@@H]==O(C)C=O
# nn=nO((nCnNN[C@H][nH][C@H]o[C@@H][O-][nH][nH]cccc3cnccccccccccccc==(([O-]1[O-]O
# 1ncnnnnncccccccc==c[C@@H][C@@H]c[C@@H]c[I-][C@@H]ccccccccc3cCccCcC)(CO(C
# SSSSC(SSSSSSCSSsS)OSccOO\cccc)cccccccCc(=c())()==O=
# ===CCCOC(ClOClS\SSSSS[nH])[nH]ccccccccCccccccccccCCCc(O(cOn
# (((ccccc(ccccsSs[C@@H][C@@H]sSssSssscccc4cccOc3ccc[O-]1[O-]
# SS1Clc=c===(=C=sss[C@@H][C@@H][C@@H]s[C@@H]55s5Clcccc))ccc[C@@H])[C@@H]((([C@H](((
# 2)((((((CCn([C@H]Ccn[nH]cnnOcccnC(nc(cc)cccccccc)cc(O)
# C(1(((([C@@H](((c((s\)Clcsss[nH][nH]cnc4cccccccccc=1c=c11O
# ([C@@H]([C@@H]((c((((ClCl(ClClClO[nH]nn4cnnnncc5CcccCncccnccCCcCCCC1OO
# O(c([C@@H])cc(cC(ss[C@@H]sS[C@H]sSCsss55ccccccC3[C@H]))CC=)
# ((c(c(((((cc\ccccccccccccc)ccccccc4cccccccOO(OO=
# Cl(ClClClClClClClClClClClClClClClCln)[nH]ncnn[I-]nncccC[I-]cccccccCc)ccc1c
# =cc(O((c(()cc)ccccc[C@@H][C@@H]ccscccccccccc33)3=)O==)((
# (C((C(C((S(CcNNcOccnnnncn(nnC4cccccccccccccc)c
# cCl((s(CC((ClcscSSSSSCnScccccccccccccc[I-](Ccc))333O))
# c[C@@H][C@@H]c(ccs(c(C[nH]s[nH][nH]c[nH][nH]c\ccoccc3ccc3c)333c===O
# CCCC(SCCC(C((\\\S\\cccc(Clccccccccccc(3c3=(=O111=
# Cl[C@@H])[C@@H]CCCCCCCCc==ccO\\\cCl)cccNcccc333)3c======OOOO
# ==(cSSCCcCccSS[C@@H]S[C@H]ccc==c)c)c)cccccccCccC[C@H][C@H]C))==
# S===#==========C=(=cccCc)cCcccc)))cc)ccc[C@@H]=====
# cCc(ccccc(((Cccccccccc[nH]cccccccccccc(cccccCC))Cn
# C[C@@H]NCNCCCo[C@H][C@H][C@@H]c[C@@H]COOO(([C@@H]ccccc5cccnccc333[N-])3333)c()cc)
# 1c((((((s((sNCN(cccccnccccc3ccc)cccccc)cc=OO[C@H]1)O1
# cc1ccClccC1cc[nH]ssssc[C@@H]s55n)5[I-]nncCccncccc[C@H])c[C@H]c)(=N=OCCC)1
# n(((CC(CCOCCCCnnnOnOcnClnC5Clccccc5cccc))[C@H]ccc3cc(1
# ((ccccccc([nH][nH]cscosss[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]ccccCccc)ccccccC)(((=)=)
# cc(((cccc(CCCCCl)c[C@@H]c[C@@H]Cccc)ccccccccc)33333[N-]33([C@H])=O)OC
# (((ccccc(ccccc[C@H]3scO[nH]Os5scccccc)c)))c)cCC)CcCCCCCCCCOCNNCOCO
# S1CCCO1CcccccC)CcClsssScScccc)ccC)CCCccc=)=CCCCC)
# CC2CCCCSCCSCCSCSccCCcC(cnClcccCccccccccc)c)cc==O1
# (2((((((((((OCl)Cl(ClScc([nH]ccCccccccccC5ccccc)c=CCcCCCC)Cl
# ClC(C((((C((ClcClCc)ccn[nH]nnccc)ccc)cc3)cccc(c(====O=
# 1(=)CCccCcc(O[C@@H])[C@@H]sS[nH]S5[nH]SsSClcClClccccc3cccCCCC=))=(=([C@H](N
# (CCCC((C(SCCSssscscc4C\44c5cc)ccccccc=))c[C@H])[C@@H]2))11O((C
# ClClClS((((((ccCl[C@@H]ccccScc[I-]cccc/ccc\)cccc=ccCc===c)c)O
# ==(CCCCOSCc=(ClClOClS#Cl)ccCcccccccccccCcccC3=cc=))O)
# 1(CCcccccccc)s)C[C@@H][C@@H][C@@H][C@@H]s[C@@H]s5)[C@@H]ScCcccccc)cccc[C@@H][C@H][C@H][C@H]=(==1
# (((((C((())[C@@H][C@@H][C@@H][C@@H]ScCccc[C@@]cccccccccccccCccc)=))=)CC=
# CC1(C(CCCCCCCCnnncOnn)nnn)nncc)cccc)cccc)ccc((ScNOcc
# ssnsCcs=====[C@@H]ccccc[C@@H]cc))5CCc5ccccc333333=3[N-])=)===
# O))(CCCCC(S=sCSSSS[C@@H]\SS\5[C@@H]55cccClcc=c)33==(=C((SS
# s[C@@H]1[C@@H][C@H][C@@H][C@@H](c[C@H]cc([C@@H])[C@@H][C@@H]cSSsCl)sscccccccccccCcc()=cO=nO
# 11C[C@H]CCCCc(cccc(c)34scCccccccnccccccccc)=cc==(=C=OBrOBrBrO
# (CCNNCN(NNNCCCNOcOOOOcOOnCn4nccc)c4ccccc=c33O3)
# cccccc(cccccOc\c\5\5s\[nH][nH]cClcccccc)c)cccC==)C=C==O)COOOO)OOC
# c==CO=CCCOO(c[C@@H]cSccccccs)cc)ccccc4c)cOcc==(CC)==
# cClccncc(cSsCsss[C@@H]Ss[C@@H]s[C@@H]55554c))c[I-])cc3c3==c==1=1=)(=)
# C11ccccccccnC)Fo[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]sCs6Scc(ccccCc3=3[N+])=)==
# ===CCCC=SC=4)ClClcCl\Cl==S/5ccccccccccc)ccc==O[O-]O=OO=OOOOOO
# CCCSCCS((cClS)cSS)Clc[C@@H][C@@H]))cs)[C@@H])Clcccccccc))cc=O[C@H](OO((
# C11Cn((ClClClClClClCl)ClClc(c34nn5Onccncccccc)cc))cc(c(OOOOO
# 2((((sCC=)nClcClClnClnCccC#cc)cc)cccc(ccccOc)cccccOO
# [C@@H]CN(NCcNCCNsSScSClCClClCl(Clc=CnCnClccc)cc)Ccc===c=)1=
# (1C=[C@H]NC(ccc([C@@H][C@@H][C@@H][C@@H]SC[C@@H][C@@H]cc[C@@H]ccccccc(ccc)cccc===)==113OOO
# =C1COCcCCcccNSnccnC)[nH]n4)cncncccccc[I-]cccccccO))cnC)OO1C
# O#O#CCS========c(ClC(\Cl\SSSSc)cccc)cC(ccccSccccN
# ClClClClN(ClClcc(cc(((cncnnn4nc)c4ccccccccccccBr
# =C)CccC1\C(=)sCC=s4[nH]cCl)cc4ccccccc433cccccCC=O==OOOO
# 1cC)c((cccsN[C@@H]\\\c\[C@@H]s[C@@H][C@@H][C@@H][C@@H][C@@H]=cccccc5cccc)cc[C@H]=c=
# (SSSS(c((c\(-ClCl=)(\ccccccccccccCCcc)cc(==Br==O)
# (nnn(SCCCC)[C@@H]5[C@@H][C@@H]S5[C@H]s5ss5n)ClnCl5ClccCl)c)cc(CC[C@H][C@H]CCC[C@H]()(
# C(OSSCClClClClSSSSSSSc\cnncccccccccccc(ccccc=OO(O)
# ClClCCCCCCCClSSSSS[nH]ScOccSccc-ccccccccccc3ccc()c=Br((((
# 11cCCCcCCCOcccccccSS)cO(ccc(Clcc)cccccc))c)c)())c1
# 12((N((cCC((((ClcCcc)cc)cnnnnc4ccc33nc3cccc)cc(OC(OO)
# CCCC(cCCCO=-(c[nH]Clc=OOOO[O-]ccc3cccccccccccC===)))
# OO=cc1C1S==cNccCl((\ScCnnc)CcccccccccccCCO=OOOCOn
# CCCCC(2[C@@H]CCCssSss[C@@H]ccnsncSClccClccccccccc[C@@H])([C@@H]===[C@H]=
# (=((((c(ccccccs[C@@H][C@@H][C@@H]=ssssSccsc)cccClccc)((=(=)C=
# (11[C@H]c(([C@H]((N(N((n()c(nccnnnncncccccccc3N33c(3N==(((
# CCCCCCClClCl((\\ClC\[O-]ccc4cncccc)ccc)cccOc))cc)===(
# =(O(NNNNcCcNsNS[C@@H]sS[C@@H][C@@H]C[C@@H][C@@H]Sc55ccc5)ccccccc===C1=
# CClC2c(((c(ccc([C@@H])[C@@H]cc\s(c)cccc)c)ccc333ccc()cOSCCC(
# C(ccc((ccccCl(Clsc((cccncc4ccccc)4))3cc[I-]cnnccc(cccc
# ClcCl((SC(SCCC=CCSS(S=Cl[nH][nH]Sscccc)c[N-]cCl)Clcccccc)ccc1CN(NC
# (1CC[C@@H](CCCScN(=C=\ClScc)Clccccccc)c3cc)cc(3cC)CC()c((=O
# NCCCCCCCC(CCCCCCCC[C@@H][C@@H]C\\\\[C@@H]S(Clcccccc)2c33)))SSSSS
# Cl===(-((Cl=ClCl)SClCl)Cl[nH][nH]Cln[nH][nH]ccccc)cc)ccccccn)CcO3OOO)OO
# sn(ClN)NcNNso[nH][nH])[nH]cn)ooCloCl5ccccccccccccc[C@H][C@H]C()OO)
# cc)ccc1c1cc[C@@H])s[C@@H][C@@H][C@@H])[C@@H][C@@H]cs[C@@H]55)[C@@H])c)csccc)3ccO[C@@H]22[C@H]1
# 1OcCC(c(cc((Cccc=sClscC)55)ccc)ccccccccc==c=)
# n(n(NNNNNNN)[C@@H]\[C@@H])[C@@H][C@@H][C@@H]Sc5ClSCSScClcc=cccClcc=cc)3)3[C@H]))=()=O[O-]O[O-][O-]BrBr
# ==(((((ClClClClClSCSSc(Sc=N[nH]ccccc))ccc-cc)c))))c2c
# 11=C[C@@H]cc(cOO[C@@H][C@@H])Clc=[O-])sO)5S=SCcccccCcccnScc5ccS=CCCOOCC)CO)
# ccccnccncccc((((C([C@@H]\[nH]4\ccccccccCcccccccc===)c=
# 223)(((()s(CCcClCl(ccccc)ccccClcc[I-]c[I-]c4ccc==)c=()==OO
# N==NNN(ON\\N\\cccClnC(C5OOO)nn[I-]ccncccccc=3))))c(((((
# c111)(c1cccccnn[nH]s[nH]nnnn5))nccccc)ccccccccc==(=((
# ccc((CCClCl(ClClSSSClc[C@@H]c[C@@H]c\cc\\c5ccccCcccOcc(=c((O=)(
# (((=(NN[C@H](NSSCCNcCSC5([C@@H]c5OCCCcccccccccccccc(((()c
# =(c(c((c(c((((((SSccccccccccccccccc======O)=O
# c(c(CCc((((c[C@@H][C@@H][C@@H][C@@H]s[C@@H]5[C@@H][C@@H]s55sc)NccccCc55ccC==1)=)
# 1C(-nCCCCcCCsCSss[C@@H])[C@@H][C@@H][C@@H]CCCcccClCc5ccc)cccccc==1)1==
# 1Cn1CCCSCCCS==CCs=ssccc)ccccccccc)ccc=cc)===
# =(C===(((((OO(s[C@@H]sssC[C@@H]s[C@@H]s5sscccccClSc)ccccc===C=(
# C((((((Ccccc((((c=nnncnc54ccc4c44)ccccc==cO=
# c==((CCClCl(Cl(ClCc(SSS=SScccccccccccccc(cc===C()=
# ==C=cccc(ccCccccccNcs)o[nH][nH][nH]o54cccccc-ccCc[C@@H])cCCCC
# cCl1ccc((ccc(ccCCCl)[C@@H]4545)))4ccccccccccCcC=C===)OO
# c=CC(CCCCCcccSc[nH][nH][nH]SCC[nH]ccCClccccClccccccc33OO
# ((((((((((ClClS(SSSSsS)cccccc(nccccc)3c)33c(====
# C((SCSCCCCcCCC\\[nH][nH]nccccN)ccc)cccccccccc)O3c=cc=C
# =CNCC\SSCCCSCC\\s[C@@H]CSS[C@@H][C@@H]\SSSSc5ccc(cccc3cc)))C)
# CC(ccnnnCcc(SCss[C@@H][C@@H]5[C@@H]s[C@@H][C@@H]sccccCl)cccccc)cc(c=Cc3[C@H](==(C(())=N
# c(1((cC((((((==(C=CnnnClnnCcccncccccn3Ccc=))c)cnCC
# (c===ClccccccscssSsSSsS[C@@H]SSSCl)cCccccc[C@@H][C@@H][C@@H]==(==)O=C)=
# cCl-Cl(ClccC(cc(=\s4\sss)cccccccccccccc[I-]ccccCC)cOO
# 11ncc(c(c(cccOcccccccccccccccccccccOc=C===c[C@H](O
# 11NNN(N((NNN(O(OO((OO(OOO3nn)CCnccccccccOOOcOO(OO[O-]O[O-][O-][O-][O-]
# ClCl=CC====CCClClCClClClcss)cc)ccccc)[I-])cccccccc=ScCcC(C
# ccc(cc[C@@H]([C@@H]cScccc[C@@H]sccc[C@@H]cc[C@@H]cccccccccccccCCCCcCCO(OCCO
# CC21(((((((((((Cl)Clc(4(c4[nH]cc))ccccccc)cc()ccCCc=
# c2(C(()cCSCCNsClsS=sCCsCss6sSc)cc)c3)33c(O)))CO[C@H]
# CC\CCCCCCClCClClS[nH]SCsSscC[nH][nH]c)cccccCccccccccccccC=)()C
# 2(C(CCCC(cc((Cl(C([nH]Cl4[nH]nnn54n)ccccccc3cc[I-][I-]ccccC()c)
# ==(((((((c((((((Cl(nccCnnnc)4cccccc=cc)c33cO)CC)COO
# c=C=CC(N(ClClCl((Cl\)\[nH][nH][nH]n[nH]nnn))cCc4Cccc=5cccCcCc3OC
# C==NCCNNNNNNN\N\\[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]\[C@@H]\\[C@@H]cccc333[C@H]3[C@H]))===1[O-][O-](11111(1
# CCCCClClClCl(ClClSSClcS(ccCClcc\cc4c4c33c3ccOcCCCC)()C
# C(((((ClC(ClSSCSSSSClc[nH])[nH][nH](Cln4ccccccCcccc=)=c(=c=[C@H]=OO
# ==(==CC\\C\cCcC\\c)cccc[C@@]\c)c)c)ccCccccc33)cccc=c
# N==(NNNNNN\\N[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]cc)O5(4cc5ccccC3)[C@@H]3cc))c(
# 2[C@@H]CC(ClClClCScClcClClClSnnnnsncnccncccccccccccC1[O-])O[O-]1O
# C(1((NCcc((((cc(Cl(ClSccccccccccCccc)Cc)cc((c=ccccOcO=OOOOO
# (CCCSCC((c((c[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]c[O-][O-]O[O-]5cccccNc5cccccC(CS(CCcCC)CCC(O
# #ccc(ccccnnccs[C@@H][C@@H][C@@H]Sssssssssscc))cc3c333=2)OO(C
# ((Cccc[C@H](ccccc([C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H])cnCCcC)cccccCC=))cCc
# OS=======OCOClClcClClClcc[nH]5nnnncccccCcc)ccc=CCcC)1=
# 2[C@@H]NN(CCCCCSClClcClClcScCl)c[nH][nH]n)cccccc3)c3c[I-]ccc((Oc(=))O(1)O
# =1FCC=N((c(=((((ccnnnnOnc(nncCcCcccc3ccccc)cc
# 1C2([C@@H][C@@H]CCCCCCClNCl((OClClnClnnn)cnncCc3))c3ccC3=c3C33OOO
# 1nnCCCCnCCC(s(cccc)ccccc4ClcccClc)cccccccc[C@@H]1
# ccccc(c((c(ClcCl1\Sc[C@@H][C@@H]ss)sC)cccccccccccCcCCCcCC((
# Ccccccn(CccC)CO[C@@H][C@@H]\[C@@H][C@@H][C@@H][C@@H][C@@H]ssCc=Ccccc)ccCOcccC)ccCCC=(
# (=(((c((((c(csss[C@@H][C@@H]s[C@@H][C@@H][C@@H][C@@H][C@@H]s[C@@H])ccocccccc3)cc1==C=O=OO
# 1cCc((ccccccOc(ccccCcnccccccccccccccccScc====
# C[C@@H][C@@H]sClClNcClClClcClCl(Cl)Clc)c[nH]c)c(4cccc3ccc(((c=)=)
# 2C(cC([C@@H]SCCCC(NccSccccccccccccccccc3ccc(===1))c=
# ccc(Clcc(c(cc[nH][nH][nH][nH]S[nH]snsoCo))cccccccccccc=
# =C==CCCCC(CCS(s[C@@H][C@@H][C@@H][C@H][C@@H]ccc[C@@H][C@@H][N-]\ccc3[N-])3ccc=1)===
# (SSSS=SSCS=OClcc=nc4nnnCnnnnccc43[I-]333cccc)cO([O-]=)BrOO[O-]OO
# [C@H]=NCCC=CCCCSCOO(O)Clcn)nnOncc()ccccccc3c=(======
# N(SCCCCCCCC(C[nH][nH][nH]s5c[nH]nnnCncccCcccc3333===O(===O1
# Cc(ccc(cccco[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]s555sClc)ccccccc=ccc[C@@H]==
# cc)ccc1cNssCs\)\[C@@H]\\c[C@@H]sssN[C@@H][C@@H]cccccccccc)cO[C@@H][C@@H]))=
# ClCCCOcClcCOc=\ccc=[O-])cncsncnnnnccCl5ccccCcCCOO=======O
# NN[C@H][C@H]C(\C(CCCCCC)Sssccc5c)ccccccccccc3c[C@@H]=====(((
# CNCCCNNNCCCNNCNCCCCcCCCc[C@@H]55[C@@H]5cccccccc[C@@H])cc333[N-](3c()(c
# 11CCCC((CC(CCCCSOOnnCnnO)nncCn(3cccsCccccc=())c=(1=[O-][O-][O-]
# cCCC(cClcccccSccCc[nH][C@H][nH]O[nH][nH][nH]CCcc)cccccccc=c=c=)C)O1O))O
# N(NNCCCCCC=CCCCCcOcClCClClc4cOcccc)ccccccC)3cc))S[O-][O-][O-]([O-][O-][O-](
# CCOCCCCSCCCCClClClCl)ClClClClClsSccccccccccccc3ccccc)ccc1Br
# c#1cc(cc[C@@H]cccscC([C@@H][C@@H][C@@H][C@@H]C[C@@H]\s[C@@H]ssccccClcCcc33Clcc))C==CC)
# =COSSCSSS==C[C@H]sscss5[C@@H]ssssSSccCcccCccccc==c(=(=S=)
# ((((((SC[C@H]SCCSNCSCCss[C@@H]5555555ccc3)4ccccc=[C@H]3=(==
# cccccc(cc(CcScOSc45Cl5C555\5c5ClccClcClccc===)=1))=1=(O1
# (==cccccccnncnnn[nH][nH]555555c554cccc)ccClc3c(c)(=11)=)1O=C
# 11((nnCCCCCcCC(C(O[C@@H]c)ccC)ClCCccccccccccc[C@H]==
# nccc(((cc(((cc(ccc[C@@H][C@@H][C@@H]ccccccc4c4ccccc3cc[C@@H])cOOOC
# CCCCCsCCCS(CC(ClCSSSCn4c)4c3cCcccccc3333cCOc33cn
# SO=CCcc\ccc(ClSS=SSSSSSS\\\cc[C@@H]Ccccccccc(c((C)[C@@H][C@@H](
# cClcsc=OccCccCcc[C@@H]c5\[C@@H][C@@H][C@@H][C@@H]))[C@@H]c5cccccc=(3[C@@H])(===2O))CC((
# 2C=cN(cc((((3\\\=s[nH]nnnnnn)ccccccccccccccc=OOO=O)O
# 4CcC(CCNNcC(oc[C@H]OOO=OCNCnnCC4nncccccc(=c(ccOO)OOOOO))O([O-]=OOOOO[O-]
# 1nCcN))NcNNcNCN(cS[C@@H]CScCl5Cl5Cl)4)ClccccOccccc(c=Sc
# O1C11CC=CCCsCss[C@@H]=CSScSSSCl[C@@H]cCcc5cc)cScccc)c=1C(
# Cc2CC(\SC((Cl\S\SSSS(SSnc5c4Clcccccc)c3)[C@H](==(=(=
# (nccccCNsss[C@@H]c[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]sC[C@@H]n666cCCl5ccc=ccccccccOc[C@@H]NNNN
# c=((cCC(((ClClClCCl\\c)ClcCc#nnnCcccccccccccccc)O()
# 1cccc(((((cc(sS([C@@H][C@@H][C@@H][C@@H][C@@H]S[C@@H]s=scCc)cc)c4ccc34ccClCC3C[C@H])CCClC
# CnnCC([C@H]([C@H][C@H][C@H][nH]osss[C@H]s)ssS[nH]sscCl[C@@H]cccccccc)c====(=
# c==COc(C(c(cccccc4OcClccccccccc)ccccc()ccnOO1
# CCC(C(CC(CCCCCn(n(nnnnnnCCnnCCccnccccccc3cccccc(
# CClc==((((cc(ClcC((Cl(ClCC[nH][nH][nH]nnnc4cCcC)cCcccccc)c)c
# ((CcC((c(((cc1[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]5[C@@H][C@@H][C@@H])[C@@H]ccccccccc)cc)c(cc)(C
# cc(c(SccCcC((=ClClClClSScClc\\5\cccCcccccccC=CC=)))C
# cc2nnccnCn[nH][nH][nH][nH]ccC[C@@H][C@@H]csc[C@@H]s\c[C@@H]s3ccc(c)3cc=)=C)=1=)
# cn((NNNNONNN)c)[C@@H]co[C@@H]5C55554c554c53ccccccc===
# Cl[C@@H]N((((((((((ClcSc()cccScc=5ccccccccccc(=CCO3))CCOnC
# =23c(((CCC(ClCC=cs)ccncnnnncccccccc33)c)cc)=O)1
# cc1(1Cl((ccccccc((c)cc)ccc()cClccccOcC33c(=11[N+]O11
# (((((c((((cc(sssss)[C@@H]sssss)ccc\cc)ccccc[C@@H](=cC=cc(
# CCCCnccCooCo[C@@H]ssOO[C@H][C@@H]SsOssssscccC[I-]ccccccCCCc[C@@H]S)cC1
# CCCC(CCCC[C@H]C[C@@H]C[C@@H][C@@H])[C@@H][C@@H][C@@H]ssSClS55ccccCccccccCscCCC=CC
# CCC=CCCClClCsCCO(ClO\[nH][nH]ClnncccC)cccccc)cc=cc=)3===[C@H]=O(OO()
# ccCc((ClClCl(ClClCl)Cl((S(sC5SncCncccc)cCccccClccc(C=======
# cc([C@@H]c(cccccCl[C@@H]Cl)sc[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]cscccccc)cc3333)c[N+]11O1([O-])(
# 1(nCnsCco[C@@H][C@@H]c[C@@H][C@@H]\[C@@H][C@@H][C@@H][C@@H][C@@H]SSs\S\NSccc)cccc==(
# c(ccc(c((ccc(cc(ccccccc\cccccccccccccccc(cnBr
# ==N(ClCCClClSC(CClClClClClClClcccc)cccc)ccccc333)333Occ)
# 112[C@@H](sCC(N((===)ClClClC[nH]n)cn#)Clcccccccc33cOOcc=)
# ccCScsc(c[C@@H][C@@H]cccccccCcccccccccccccccccc(cc=)1=C
# 1((cO=O=ccCSsClsscssSn5[nH]ClccccCccccc)ccccCCC)(CCC
# C11(cCcCC(c(CcCcSccCCccccccccccccCccc)c(=(((((1
# SSS1SScCSN(CScsc==sc=c=C===c)ccccc3Cc3O3=O=3(3O(O
# C=NC(((c(ccccc=[O-][O-]cccccs=cccc[I-])c[I-]ccClc)cc33c3)=())))
# 1C=C==(CccNcCClSSSscc)cccccClcccc)ccc3=3c3===O====OOOOO))OOOOOOO
# =CS(([C@@H]c(cCC[C@H]CCSCCs)s5455cccccccc3ccccc=))=(=O==
# 11(C)Cnnn)nnn)nOOnnnnO3n)n)NCccc)cc)cOcccc==Nc3c3c)ccccc[O-]ccc[O-]cBrcccccc111Br1)11111111111[I-]1111111Br1Br111Br111111Br11BrBrBr
# C[C@@H][C@@H]3SC[C@@H]S(\[C@@H]csN[C@@H]cccCc)cccccccccccc)c3cc[C@@H])[C@@H][C@H])=)
# ==((cc(cClcccc([C@@H]scccS)csscc\)cccccc4cccc())=(((((OO=O)OOn
# 2CCCCCCCClCl(ClClClClClnClCS4[nH]c)4c44cccc)cc)4c3Clc3c3Oc3OO)
# Sc1=C\\cCNcsCCss[C@@H]ssC\=s[C@@H][C@@H]ccccccCcc(cc[C@@H][C@@H])CO===()O
# 1(NCNNNNNNNss[C@@H]o[C@@H]c[C@@H][C@@H][C@@H]5555[C@@H]555ccccc3c[N-]cccc==((=((
# OCC2C[C@@H](((((Cl\ClClOO\sCl[nH][nH]c[nH]Sc)cNccc)c)ccccCCc(cc)(
# 2[C@@H]((((O((((Cl)Cl\)[C@@H]cCCccnccccccccccC)ccc3cc=ccO=
# cccccnn1ccCc[C@@H][C@@H][C@@H]C[C@@H][C@@H][C@@H]C[C@@H][C@@H][C@@H]54c4)c3ccccccc=c[C@H][C@H])2=O(
# 111(((c(ccCCn(OSCS5[C@@H][C@@H]s5[C@@H]scC)cccccc)cccc3[C@H]))O((C===
# ccnccccccccc((ccc[C@@H][C@@H]cC)cccnccc4cc433===([C@H]==O
# #CCC[C@@H](\cc(ClClClClSSCl\SccnccnccccOcccccccccCccccc)
# 22222)([C@@H]C(sCs(csCCc)ccccccccccccccccccc=)=O===(
# Br1(([C@@H][C@@H]1((1(((\)(()[nH]44on)o4n3c3c3cc3ccc3c)cccc111BrBr1
# =(C1[C@@H]((Cs\\CCls\[nH][nH]nn55n[nH]ncncCcccc334333333Ocncn
# O==/\sccNCNccC[nH]1[nH]555Oc[I-]5cClClClccClCl=)ccccc33)33)==O2=1
# Clcc=C(((((\\\\\(\c)Cccc5ccccccccccccC===
# sSS[C@@H]([C@@H][C@H][C@@H])[C@H][C@H][C@@H][C@@H][C@@H][C@@H][C@@H]S[C@@H][C@@H][C@@H][C@@H]\\\\))\c6cccccC[I-]CcC[C@H]1OCC2
# ClCCC(((((Cl(ClClSClClCClnnnnn[I-]ncccc))Ccccc)Ccc3CCCcCC
# ncCnnn(c(cOCl[nH]sO[O-]sSsCssss)Scccccc)ccc=)==C==(==
# Oc====c=cO((ClCl-C\\4\3o[nH][I-][nH])ccCcccccccccc3cc=[C@H])OC=Sc==O=F)nO
# cccn(SCcS(SCC(SSS[C@@H]c[C@@H]Sccccc)ccc()c)ccc(==1(1=
# #n=ccncCccc[nH][C@@H]SsS[C@@H][C@@H][C@@H]\S[C@@H][C@@H]SSS[C@@H]ClcClccccc[C@H]====O==)==
# 112(ccn(CClccccClCl(cCl(ncc)cccCc)ccccc)cc)))cCOcc
# SC\\SCCCl\SClC4[C@@H][C@@H]\ccccCC))cCcccccccc)C4cncOc)ccc)==C(C
# ClC=O(c((c(Cl(ClClCl(Sc=)ClCl[nH]cccccc)ccccccc=(()=))c=
# ((=C)CCCCCCCC(Cnc=nnnncnOnOc33cc3cccccccc(c3ccccccBrBrcBrBrBrBrBr
# c((((((((c(SC\\Cl\\\\sss[C@@H]Clsccccc45cc)cc====))CCOOOO
# Cl((((ClClccClcClClClSSccccccnc/1ncccc)ccc3c3)3=)OO3OcO
# CSSSSSSSSSCl=SSS\SS=Sn[nH][nH]cnNccNccccccccccCcCOC==c1C
# s[C@@H][C@H]=NCCCCs[C@H]cCss[C@@H][C@@H]s[C@@H]csccC5C[I-]CCc5ccccccc((((S)((
# (N(N()N)scN[nH]oo4[C@@H][C@@H]ssSssss5ccCcCcccccc)c[C@H]c[C@H])===C
# Cc((c(c(((O[C@@H][C@@H]S[C@@H][C@@H]c[C@@H]s[C@@H][C@@H]ccccNc)\cccccccccccCC)()cc
# 111C=C(CC(ClClOCl\S[nH]Cl[nH])nCnnCcnnc)ccccccc)3==)cC)c3CCCCCOCC[I-]
# 11Cc(SC(cCCCClCl(ClClClClnnncnnncccCc33333cc=)c1nO11O
# =([C@@H]1[C@@H][C@@H][C@@H](ccc[nH]s[nH]s[O-][C@@H][C@@H][C@@H]ss[C@@H]sss)[C@@H]cccccClcc(cccc[C@H][C@H]=(=(
# =OOccSCcCcCOOOSSs[C@@H][C@@H][C@@H]c[C@@H]cccc)c4cccccC)cC===(=O(C=
# ClClCl(ClClClClClCl(ClClcClClSSSn)cnnccccc4ccccc)ccC)CC=)1()c=O
# cc==c((((c((Cl\cc\cc(3[N-]\)n[I-]ccccccCc3c)cc3cc=c(C
# CCOC(CCCcsCCcccccccC[I-]c5Cl[I-]ClSSClClcClccccccc3[C@H][C@H][C@H]=111)[O-]1)
# 2(([O-]cCCC(cCCCNC(ClClSCcnC)nncccc)ccccc3ccc=O))))=nOOO
# (cccNCCCCCCCC[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]c5554Clccccccc[C@@H][C@@H]c()c)[C@H]1)
# CCCC(CC((N((ccnccccOccccccCl55c5cccccc3c[C@H]c3c))ccc)))
# Cl2[C@@H]((c(((=)ClCl)ClClClClClClClnnnnnncccccccccccc)3ccOC)3=O=OOOOOO2O
# (C((SCCCCCC(\CClCl)ClClc[nH]cccc)ccc)Ncccccccc)ccOOcOO
# ((S[C@H][C@H]11SSSS=CCCCCCCCCCCOCC=========c=cccccccccc1c[N+]Br1Br[O-]Br111111111111111111111111
# C=cCcCl(((Cc[C@@H][C@@H][C@@H]=S[C@H][C@@H][C@@H]=s[C@@H]sss[C@@H]ccccClCccccCcccC==)c=(
# Cl=OSSOCS=OOO(Cl(cCl)Cl[nH](4ClClnnncccccccccc)cO[C@H]cOO)c111O1
# =((==ccc((cccS=CScnCl[nH]ccCccnn[I-]ccccccnccccc)ccc
# 11[C@@H]2Cl((Cl(ScClcCCccc\ccccC)cccccncc)ccc)Ccc(Cc=n==
# 1nOccccccccc)ccccCs[C@@H]cccc)cc4)ccccccccccccc)=))=)===
# (CCCCCCcClClClsClClClClClCl[nH][nH][nH]nnn4c)c))ccc3c3)c)c===OC==(OOO
# 12CCC[C@@H]ClcCcc(C-Cl)s(-s)oooccccCccc333cCccOcccccOcO)
# ClClC====C\(ClClClClcc\\S\)CcccClccccc\cccc)cccccc
# nncOcOcnOcCl[C@@H][C@@H]o[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]SsCCCCl5ccClCl)cccccCcC[C@H][C@H]CCC[C@H]O))C(
# 2cCC[C@@H]cC(=NClC(SsCSCCC)=CSClClncccccCcSCccccc(C(CCC((CC))(
# 1c1c(N(NNNNCCCCCcCCc))[C@@H]cc)))3c)c3c3c)c()3O)c(
# [nH]\CClcCSC(CcClClc[nH]S[nH]C[nH]ocClClClClcClcccClccccccc===C====C
# c)nc1(C(cCCSnnNcnOcOnnnOO3OcnCCccccccCCccc(33c(c)ccc()(c)cc)111111Br11Br11111C111111
# =)NNNCCC(CCCccccOOcOcOOcCc(cCcccccc==[I-]c33c))cc=)==
# CClCCl(ClClcS(cc(\\Cl\Clcc\c)ccccCccccccccc===)O=)C)1
# 1CC((nnn((ccCcS[C@@H][C@@H][C@@H])[C@@H][C@@H]SCC[C@@H]cccccc)cc)ccccCCCCC((cOCCn
# 1cc(C[C@@H]((C((C(S[C@H][C@@H]Sc[C@@H]cc[C@@H]S\\\\5ccc3cccc)c)(Oc(cc=O=O=)
# n(c(c(c((c(\CsSCs=ss5))5ss))cccccc)cccccCCCCCC====
# =\ScCc(cccccSS([nH]c[nH]S[nH]SCSccccCcc4ccccccccOc=c)C(C[C@H]=
# (==N=CCCCC=cOOOsO)cOSS)c)ccccccccccc(()=)=)(
# cCCccccs)NcsSscnnCO5OO5O5)CClCOc554ccc3c32[C@H]c2S1(S(
# (2[C@@H]c(sC((sCc((Cl(Cl(cn)cC))Clccccccccccccc)=(O(=cO
# O===N===C(NsS[C@H][C@H]S[C@H]scsss55ClCl)Ccccc)c33cccccS[O-][O-]111O1
# (c((nnnnn=nn[C@@H]CccC=CCCCCCCCCCCcClClccccccOc==c)S)SS((
# c2CCSCNC(c[C@@H]cc(c(cc=5c55cccccccccccccc3333[N+])[O-]))
# c=OOc(c(CC(oC=[nH][nH]O[nH]))[nH]O[nH]nnncccccccCc3c3)=OC==[C@H]=1(
# =CCCCsc(s(ssssssss)ScsssoCo4cc)4ccccccccccCCCCSC)CC
# ((n=sOccnsSss[C@@H]cc5sssssssccccccccc)C)cccc===cc=(
# 2[C@@H](CNNCCscCcCC=Os[C@@H][C@@H][C@@H]5scsscClcccc[I-]cc)cC)3c[C@@H]==))C)CcCCC
# cc[C@@H][C@H][C@@H][C@H]((((c((ClCl(\ccccc))Clc)c3cc)cccc)cccc=c(c)c)
# 2((((((((((([C@@H])[C@@H]c(([C@@H][C@@H])[C@@H][C@@H]cc(ccc))ccccccScccO=c(=======
# ((((((((((((s=[nH]CO[nH][nH][nH]occccnccCcCCccc)cCc(CScc)CCCCCCO
# c212ccc(ccccOcccccccccCccccCcCcccccccScc===O=CCCC
# (1nC)(CCCCCCCCCnCcCCcOO=C5ClcClClClClClccccc33=s3)3=)==
# C==(=cc(((ClS(SSS)ccccncn)cCcnccccccc)cc3=O3O=OOOO
# 2s[C@@H]1c(ccccSCCCcnCCCCCn=CnCccccccccC3cccc))))c)1
# n((SCCCCcCCCO[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]5s55cc)5cc(cccc==c[C@H]===
# 111C((()(ClN)ClClClNs[nH]c(n[nH]oc)[nH]c4ccccccc3cc3)))C)))(C()
# ===2C=CCC((NSNsSSSSScOCccc)ccc)2cccc3c)3O3(O)
# CSC((((cccN(\Cl(SCSc(cCCcc4ccccc[I-]cccccc3=)=)cOcO
# =\Cl2(S(ClCl(ClCl=Cl(ClClCl[nH]Clcnc5nnnc)cccncccCcc==COCOO
# ccc(c(((ScCCs[C@H]S[C@H]sss[C@@H][C@@H]N[C@@H]csC5[C@@H]c5\\c3C4c===S=1=)=1==
# ==((=CCCCCCOOOss[C@@H][C@@H][C@@H]sss5[C@@H]sccccccccClcc====(===O[C@H]=OOO(O
# C=OCCCCCCCSCCCcClcCc[nH]cn)cc4cCcccccccccccc3c(=[O-]=1[O-])
# =CCCCC(\(SCcClCl\ClccccClcnn)ccnccnccc)ncc)cc)C=ccc
# cCCCCcc(c(ccccc===ssSCcccCcccccc)3cOcCC3===)C=1
# [C@@H]s)s)ssssssss)o[C@@H][C@@H][C@H]))[C@@H]5snnClnccccccccNc[C@H])[C@H]c[C@@H])[C@H]c[C@H]Sc1
# ccc(cc(c(ClCClcO[nH][nH][nH][nH]s)sccccCccccccccccccccc=====(
# #1===(CccCl(ClClClc\[nH][nH]\[nH]cS5cccccccCcC)ccccc(cc)cccCScCC
# N1)(1c(((SnSnnClnnClClClnnnn)nClnnCnccccc3cccc3c)cc(NN[C@H][O-](([O-][O-][O-][O-][O-][O-][O-][O-][O-][O-][O-][O-][O-][O-]
# (CcCCNNNNNNNNcnccccn(nnnnccCcCcCccc33ccc))113)[O-]1[O-][O-]1
# ((((c(((((c(c([C@@H]([C@@H]Sc[C@@H][C@@H]=c[C@@H]c)cccccccccccc(C[C@@H]cOcc
# CCCc(ClcCcSCCCc(SS=)sSSsn=C)ccccccccccSncc)ClC[C@@H][C@@H]c)C
# C21C=CCN=C=CClSCcSncC)ccccc4ccccc3c))cc1c=
# Occc(((((((S(cSSSSSSSS[C@@H][C@@H]c[C@@H][C@@H][C@@H](cccccccccc[C@H]()=(=O==(
# ClClC((sCsCCCSc=CccncnCnnnnncncccc[I-]ccccccccccCcCcC
# c==([C@@H]CCcOO=OOClcOccccccc455Clccccc)ccccc====
# 1111(((cnnn(n(nnnncnnCn(nnnnn3cccc3Ccc3c3ccOcccccO)c([O-]11(
# 1nn((([C@@H](ssss[C@H][C@@H]O5ssSsssS[C@@H]sSSccClccccScccc=)=cS==2===OO=
# CnncnnC(CC)[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]5)5ClcccccccccCccc(cc)(C=C)
# Clc([C@@H])(cCC=cC=N=c[nH])[nH]Clc)Clcncccccccccccc)c==cc=
# (1((((([C@@H]([C@@H][C@@H]sCSCss\SSsso)ss)ccccccccccc[C@H])(O[C@H]1(=)1
# OCCCNC((NNCNC(NNcccnnnnnnnnn(nCccccccccccccc)(1
# C(-ClcCCC((([C@@H]((()[C@@H][C@@H]CC[C@@H])[C@@H][C@@H])6scClcccccc)cc==S===(C([C@H](
# =(C(CCCCCCCCC=\\O[C@@H]O[C@@H][C@@H]55\)c5ccccCcccccccccc(O3O
# [C@@H]C==(((((c(Cl\c44\)(c55c)ccc4cc3cc3)ccc(cC()c====))COO
# n(cc((SCC(CSSSS=ssO)cClc)ssccc)ccccccccc=)(((=)(=
# 11C((C(c(((ClClClClCClCl)(ccnncccc)c5)444cc=c)==)C=CcO11
# sC==OOCCCCCCcccCCccc[I-]O422n)cccccccc)cccc)c3cO)c)OOO((
# NNCSSN[C@@H]\SSSSCS\SSSCSCCSSSSsCSccccc3Nc==3=O[O-][O-]33==(OO
# =CNNCl)ClC)CsscCCCCCSCSCC5553cC4OOOccCO)[C@@H]([C@@H]=[C@@H])((()
# Ccccc(ccc(cc(cSCc(cccCnc5ccccccccncccccccc()=OO)=
# cc((((((cc(ScSScOcnO[nH]ncn4ClClccccccccccccc(OCCCOCCCC
# 2((2[C@@H]CsCC(((((SSC\c)[C@@H]c()cccccccc3Cc33cccccccccccCc
# c=O2ClccsCccc[C@H]=[C@@H]sC[C@@H][C@@H][C@@H]cc\)\)cClcc\ccccccc(C==((===
# 1c(c(ccnnnnOSS(==ccccc[C@@H]c)ccc3ccccccccc)c)cCc()c
# cc(c((cc(ccc)cc(ccccnncnnnnccCc3ccccc33OcC3OcOc)Cnn
# ClC((ScccccCc[C@H][C@@H]SS[C@@H]\ss\s)ccCcClc=c5cClcCcccCC=C=CC=C1(
# ccc(cc(((c(Oc([nH]o[C@@H]o5o55555c5cC5ccccClccccc==c=c==C
# C1[C@@H]([C@@H][C@@H])ccCc)[C@@H]ssssO[C@@H][C@@H][C@@H]ssccClccccc[I-]cccc==C)))C))C)C
# ccccc(Cln(c(c[nH][C@@H]ssSscss[C@@H]ccccccClccccccccccCC=cC
# OCOCCCCCC(N)COoo[C@@H]scnCnCnnnCccncccccccScc[C@@H][C@@H]Oc1[C@@H]
# 2(((((cCC=)ClCCCCcCc)ClnnnnCln)Clccc4c=cccCc=c()O(cO)
# 1((((((c(((()cCl[nH]n[nH][nH]C[nH]o[nH][nH]5[nH]))ClccccccccccccccCcC=(
# ccc(ncnccccc[nH][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H])\ccccc)Cccccccccc(nn
# c[C@@H]ClCSn(cSSCSCSC=OOOOs5c65cccccc)cC[C@H][C@@H][C@@H]CCC==1
# C(C(CCCCCCCCSCCSnCOOOOOOOOClnClcncccc)cccc[C@H]33N=(=[O-][O-]
# S11c)c(\cC[O-]sccClc\ScCccCccccccccccc))cc((cccO1O=)
# (((CC(C((ccccNcccccccncncccccccccccc)c3c)c1
# c((((((c((c[C@@H]c([C@@H][C@@H][C@@H]S[C@@H][C@@H][C@@H]Cs[C@@H]cccccccccccccc)=(=)(==(((1(((
# ==C=((cNcSCcc[C@@H]cscccc[C@@H]ccscccccSccccccc[C@@H]===OOOO
# ((c((c(cc(c(c((cssscc)cccccccccccccccc3nn((1OOO
# (CC((((CCC[C@H][C@@H]cc=[C@@H][C@@H][C@@H]s=5s[C@@H][C@@H]CCcccccccccc3[C@@H]CO=O=O=
# SO=====1ccccncccCcccccc)cN\cccc)cccc)C3c=(=(1=)=OOO
# 111cnCc(nNCCcnnnnOClO)ClcOccncOcccccccc3cccc=cCc)
# nc1((cc(c(Onnnnnss[C@H]SsC[C@@H]5C[C@@H]5)cClcc4cccCl))cc))ccC(
# CCCCCCCCCCOCCnnnOOClO34n54O5nClcccccClcClcCccc(()=)[N+]))1S
# 11c===cccc[nH][nH][nH]ssss[C@@H]sssss5[nH]ClO))cccccccc======OO1OO2
# ((=nc(cccccc[C@@H])css[C@@H][C@@H][C@@H][C@@H]S=sCC)Clccc)Clccccccccsc=((=
# (=====5N==CClCC==SClClc)cccccccClcccccc(==O=O)====O
# ===((CCCCClCl(ClSSS=scccccC)CClCl)4ccccccccC[C@@H](C)c=(
# 222\()\(SCCc==cO===C==c)cc)ccccCc)ccccCCC===c)===O=OOOOOOO
# ...
# CC[C@@H]==(=(ccClc((CCl(cSS[nH]\\5\cc)cccccClc)3cc(Cc=)CCO)
# cccc(c(((c((c[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]\5cc(cccccccccccc)===
# ==CCCCClCClcClCSSssssc[C@@H][C@@H]sssClc)c)c[I-]ccc3ccc=)=(S==)=
# C=N((((\(ClClClCl(CCl((Clc)ccccc)ccccc)cClccccc=)=(==O==OO
# c[C@@H]((c)((c((ClClcSSSSnCOO[nH][nH]6cc4ccccccccccC)[C@H]=(()))C=O
# =CCC[C@@H]ccccsCsss[C@@H]ssssS[C@@H]ss[C@@H]cc4cccccc3c3cc[C@@H]
# NN((cNNCCNNCN[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]C[C@@H]5CCClnnClcccOcClcc)ccccc[C@H])(1Cl)(=O[O-]
# Cn)(c)n(nnc=CCCSSCSSSSSSSSSClc=Cl5ccccSccc=[N+]S3===
# ccc1cnnncc1cc[C@@H][C@@H][C@@H]c[C@@H]cccc[C@@H][C@@H][C@@H]cc=cccc4c3))33=3[C@H])[C@H]
# nCCCCCCCCCCcOcOcOOOClClClClcClClClClcccccClccccccccc3(=)))=)Br)
# ClCC===CC(CCCccOClccccccc)cc))-ccccccccc3c1OO)O
# 2CC[C@@H](CCCCC(SCCSScnCC=ss)sccNcccccccccncc(C)cOOOO
# cccCcccnn([nH]cNossc[C@@H]cccscocc)cccccccccc)===
# C1cc((c(((4ClClc(ClcN5cccncccCClccccccccc)c(=c)=)=)
# 111))[C@@H][C@@H]Cs((cClClClc[nH]sSccCcccccccccccc)ccCcc3cc)cc)=OO()=OOOO
# =OCl(\ClClClCl(ClClCl)ClClClClClClCl)c\)cc\cCc)ccccccccnccccO=C
# cCCCnncCCCsss)s))))[C@@H][C@@H][C@@H])4[C@@H]4cccc5cccc=SOc)ccccc)c[C@H]c111
# CC(([C@@H]((()(\\\)cc[nH]cS[nH][nH][nH]cccccccccccccc(c===O(O==On
# cc()([C@@H]([C@@H]c(SSsCSCCSssC5sSCs5scClcccccccCCCCCCCC
# cccCSCCCCCCClcC(1)1)[C@@H]cccccNcccccccccccc===(c=[C@@H]c
# (C((C(((ClClCClClCl(cClsC[nH]Scncccccccccccccccc3=O)OOOO
# C(=CCC((ClClClClcS=SS===[C@@H]C[C@@H]scc[C@@H]ccccccc3)c======
# Cl(((((Cccc[C@@H][C@@H]C\ccsC(\cc()cccc-ccccc3ccc3))CO(O=)O
# ClOOO12c[C@@H]cc\cc(\\\cccccccccccccccccccccc(=O=O==O1O
# CC=Ccc=CC===CC=NNc=cCC=CCC=cc5Clccccc)[C@H][C@H]=)3c((11111
# CcCC=COnCCCCc=C[nH]=sS[nH][nH]C[nH]=S)ccccccccccCCc)[C@H]====(1C)
# nnnnncnn(cOOs[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]c55cccccccccccc=cCc[C@H]O[C@H](C=(
# N1111)(([C@@H][C@@H]CCc5ccccSccccccccccc)ccc)4cccOc))))[C@H]C
# n(nNCNcNCCCC[nH][nH]Cn[C@@H][C@@H][C@@H]coCCcC5CCcccccccc[C@H]3[C@H][C@H]OO(OOOO[O-])))
# ===CCCCCCCCCCCS([C@@H]cc[C@@H]c[C@@H]cc\Clcccccccccc(===)(OO)OnOOO2O
# (((((Cc(ccClClClClClClClClCl[nH]SScClScc)n)cc[I-]ccnccc3ccccc=CO==O
# cOncccccccccco3[C@@H][C@@H][C@@H]Ccs[C@@H]5cCcc)ccccccc)ccccc=(==1
# ==O(O(cOS((c-(Clcn)nnnnnncncnn4cc)3ccCc3O3cn1OO
# cc((Sc(ccccScSccSSccc)cClc)cccc)cccc)ccCc(==((O((O(
# s3CCCCC(CC([C@@H]=)O[C@@H])[C@@H][C@@H]C[C@@H]NN=ssNccc5ccCc=ccOO)O=))=C===
# #C1(CCSC=C===([C@H]=Os[nH][nH]Sn[nH]SClccc5))ccc)Cccc[C@@H](ccc[C@H]3)c)
# ClClC(cc((ccs==cnccnnnClCl4nc)4)44c33cccc3==c=nc1
# csccc((([C@@H]c((((C\cnccnc)cc)cCccccc)ccccccOcccc(cnBrO
# ==2==NOC(CccClClCClCl4ClClCl)ccccClcccccc)ccc)ccCc)))ccC)C
# 222c([C@@H]ccccClcccClccCccc1Sc\\cccccccccccc)cO=cc
# SSSccc=C===cOcc\cCl[nH]C[nH][nH]44[I-]ccccc43ccCccccO)CcOnnOC
# 112CS(CCCCc(cClClClCl\Ccccccccccc4c=c4c3==3)=(===O=O=O==
# CC===cSc[C@H]\csccss==ss)sCccc[I-]/ccccccccccccccc==OCCCCOOOOOOO)OC
# n(C(=cCc(C((c=cccNClc=ccc)ccccccccClccc==cc[N+]C))O=
# Cc(CCCCC(cc(cCCo2ccocnnoococcccc3cccc333)3c)[O-][O-][O-]1
# nnCCCCCCCClCNSCCSCSsSSSs[C@@H][C@@H])ClcCccccCccccc)cc)c
# 22CCC(SCCCCCSCSClClClClSS[nH]C[nH]ClScccc=cc)cccccCCCC[C@H]CCOO
# Cl2=Oc((ClcCCccC=cn(cncnncc3)3c4)[I-]cCc)ccc)cccc())O
# ==CCCCS(ccc([nH]ClSs[C@@H][C@@H]scscO5cccc\ccccc)c3c)C1CO
# (CNcccN=cs[C@H]cScCNs[C@@H][C@@H][C@@H][C@@H]C[C@@H][C@@H]S[C@@H]Cl)c5cc)ccClcccCCCCCC(=CCCC
# ClClCl((CClO(Cl(Cl(ClClClS\(\\[nH])[nH])cccccccccccccc)ccO))=)==))OO
# 1CC(CCcN(c(ClClClClClClCl)n[nH])[nH]cnnnnccc3c3cc3)cccccc(O=1O2[O-])OOOO
# S1BrCCOCCC1OOOc=)Ccc)nnCnCnnCccccccc)cccccOcccccccc3cNc1
# C11S=CCCCC=CCOSOOOCnnnnnOnnOOncccc3c333Occcc1[C@H]N(N[O-][O-][O-]
# 1cnClnnnncoC[nH]s)ccss[C@@H]sC[C@@H]sss[C@@H]\[C@@H]cccccc)ccccccc11
# cCCCcCccccccCcccccccCC[nH]ccccccccccccc5=cCcC)3OOOOOOO)OOC
# Ccn(ccC(C(\cc(([C@@H][C@@H][C@@H][C@@H]cc[C@@H]cccccccccc)ccc33)c=c=
# (Cc1cCNCNNNNNO[C@@H][C@@H])[C@@H][C@@H])((4(cnCnnCcCcccc)333)c3O))cc
# =cccccnccccc(ccSSSS\\\[nH][nH][nH]ccccccccccccccc)C)cc(OO(
# 2C(CCcC(ccCCClClClCl(ClSCcccnnCc4cccnc[I-]ccc3)ccOnnnn
# C===(C((C(c\SS)\\\(\(cccccc)(cCcccccOccC)))cC
# 1cCC(C((CCCCnC(OOClClO\ClcClClCOClClCl)Clccccccccccc)c())3c1c
# ((nCNc(c[C@@H]c(css[C@@H][C@@H])[C@@H][C@@H]C[C@@H][C@@H][C@@H]5C[C@@H][C@@H]5ccClCcccccCCCCCCC1CCCCC()
# CCC1[C@@H]ClCClN(ScC((cnnn)ncncccc4cccccccccnccc3ccCnn
# SO1N(((((((cCl(cc[nH](nnnCnnnncnnc43nccccCCccc1cnn
# CC(SC=CCCCC(O)C=OOnnCn55555=Cl5Clccc)O5ccc)ccc33)(([O-]([O-][O-][O-]c
# 2\C(S(SSC(CcSCSSClcSCCccCcccncccccc)Cc)ccc)c)c)c
# ClClc((((\cCClCl\=sCl[nH]s[nH][nH][nH][nH])cc))ccc3)c33c))ccc)ccc1O
# 3(5SC(CCClClClClnS\\[nH]\[C@@H]S[C@@H]C[nH]ccccccccccccccccC=====
# C(=C(SSSsSSSCSnSnnClccnncccccccc)4cc3c=cc==(==
# 1n(((ccc(ccccc[C@H]Scccccc=CCcccc)Clcccccccc[C@@H]C)C=(((
# NClON(CCcccNN(cNNN(c-))-c)cccClcccClc)c3433333cc=O=OO=OOOOOOO
# C=CCCCNCCCCSCCOCOCOOOOO5O54[C@@H]cccc)c)c)cOcc(ccc[N-]ccccNccSc[O-]ClNClSClN
# ((((((ccccCls((ClCl(Cl)cnncccccCc)ccccc)ccCO=)))OO)
# CCNCcC[C@@H]NCNCNNSCNcC\CcCC\\Cl[C@@H]ClClClcc5ccccc)c33[N-]3c2)1
# S=#CCOC=CSNCc\c(cCl))ccc)ccccnCccccccccCcc=)C==OC
# ns)nc(N[C@@H][C@@H]cs[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]555S5SClccccc=ClcClc3[C@H][C@H]c[C@H]=1C
# 2CC((OC(((Cl\ClClClClClC)Cl(ccc)cccCncccc)ccc3cOOOOOOOOO
# 1C1ccCCCCCCCcCC(C==)cC\cc(ccccccccccc)c=OOS===C1(NN
# 1n(NNNNNNNNNNNNoccccsncc4ncnClnccccccccc)(((O[C@H])(O(O(((((((((
# ((C(((=(((cCl(ClClClClClCln)))nccnccc4)cccc3==n=O1nn11n
# CCnC(((CCCcCCCc\\O\OsssClCl5Cl)5c)C4cc4cccccc(=Nc1O1111
# =OccCcccccccccc(ccccccccnccccccccc[I-]ccc=c=c===
# 1=CCCCCCCCN=sNsscsscccNcc5ccccccClccCl)=[C@H])==)([C@H]O(=(N
# 1(NCNNsNNNN[C@@H]NsNs[C@@H][C@@H][C@@H]C[C@@H]ClcCcCSc[C@@H])Clccc3c)cc)OO[C@@H]C[C@H]CC)
# Cl=C=C=CCCCCCl=c\\\\\Cl\5\[nH]ccccccccCcccC)(c[I-]CcCO==(=)
# 2(C(1)[C@@H](((((((ClcccccccClcccccc)ccc)ccccCcccCccn(
# 1nCC=NCCN\\\\S\[C@@H][C@@H][C@@H][C@@H]S\SSC\S5SSClClc)cccc[C@@H][C@@H]=([N+]
# Cn(nc(((((cnO)nnncnnncOOOOcO3c3cc3cc[N-]cccccScccccccccccn1nBr)11c1
# =N((((cc(-Cl\cccClSScscssccccccccccccnccccccccco(
# ==(C=CN(((((((((\\\\[nH]n)nCcc-c-ccccccccccS(cc(==n
# SnnCCCCCsN[C@@H]s[C@@H][C@@H][C@@H][C@@H]5[C@@H][C@@H][C@@H]s[C@@H][C@@H]Cs)ClCccCcccCcc==cC)cc)======1
# 1==((((=s(=c=(\\Cl)))O)44cc43cc43c3ccOcc[N+]==Br)BrBr1Br
# c((((c(sccc([nH]s[nH][nH]oOo4o5osss3ccNcccccc3cccc=(c(n(Ocnn
# =C(cC(((((c-[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]sOs5\55c\cccccCc)cSc[C@@H][C@@H]CCC)Cn(
# 11111[C@@H]SNccCcNNN(ccCnnn)CnnnnnncOcccccccccc))ccnnoo
# cccc(ccc1((cCl\3cC\4[nH]cnncncccc)ccccccc)cccccOc
# ccC(Sn[nH]ccScCCs[C@@H][C@@H]SSS[C@@H][C@@H]\\S)ccccccc)cC)C[C@H][C@H]=====
# O1cccCS=c===C(\c([nH]([nH])c4ccc4cc)ccccc(==O==O==)O11)(1O)O
# c((S(cNcccccccCccccccccccccCc[I-]cccccccc()=)CSCC
# =ccccc(C(ccc(O)ss[C@@H]osssccnc)5cClccC5Clc5ccc=(===(==2)[C@H]O=1
# c(cc(cCCCCCCC(SSSSSc[C@@H]c\\cccc)Cl))cc3)[I-]3c(3=c=(=(
# 2[C@@H](CC(C(\ScNccCccccCccc)cccccc)c-c)cc()c(cc)c[C@H](=
# ((((1(cncccnn((oClccCCn5)cccc)cccccccccccC[C@@H]1C==1=
# (11nncCncCCCCCcccc\c\\==45c)cccOccccc)Cc(=c===
# cCcccccccccccssc[nH][nH][nH]osc[nH]nnnccCcccc55cc3c==(==()2
# C(====C(((CcCCc(ccC(cccccccc3cccc3cccccc[O-])1[O-]=
# C((((SCCCCClccSccccScSccccccccc)cccccccc=O)c=c[C@H]1=
# 1c(Oc(cc(cc(Cc(ss[C@@H][C@@H][C@@H][C@@H]s[C@@H]ss5\\ccccc3cc3333O(==n
# C===((CCC(CCClSCCl)[nH]Cl[nH][nH]nnn)nccccccccCcccCccc))(C)11())
# n=CCCNNNSCCSSSSSnSS\\5)ClClCl)Cl5cc)cccccc[C@H]cc[C@H]===)
# 11NNCCCCSCn=OnnnOOOnnnnnnCncccccClccccccccOccccSc(
# 1CCC(=OscClClClSCCClClClClssc\ccC)cccccc)ccccOc(CC))CO=O(OO1O)OOO
# 1((sC(NCc(cccccc)ccccccccccccccccnnccO)cO)ccccc(==
# =#C====CNCCCC((\\\\[nH]554\c)3ccccccccc33[C@H]====o[C@H]O[C@H]O((
# Cl=(((SNCCCcccc(ccCs[nH]C[nH][nH]ncc)cccccc4ccccc=====O
# (C((((CNNNNssccnncCCOnClClCnC5ncccCl5ccccccOc(ccc)OOO
# =ccncccccC\[C@@H]c[C@@H]s[C@@H]s[C@@H][C@@H]c\cs[C@@H])\S)ClCc)ccccc3=c[C@H]==(
# #1Cc[C@@H]C(-ClClCClClClClClCl(ClscnC[nH]nccccccc3c3cccC==)OOOOO)O
# S1ccSCSccCS===[O-]=CcnOnnn4[nH]3c4c5ccccc====1=O=OBr=OOOO
# 11SCNCNNNN(COCC[C@H]SCCCCC(COClCcCC5cCl4cc[I-]Occccc=cc=c)
# ClClClC((((((((c[C@@H]Clc[C@@H]cc[C@@H]cc4nnccc)cc)cccccccc)c)())(
# C===CCCC(CC((CO(ccnnn(nCnCn5ccClcc)cccccccccScccc(O1)1
# =((-(O(-ClCl(ClClc=s[O-]c[C@@H]scccsscc)5c)cc)ccccCO)=((=C)C()
# Cl(((N(Clc(cCCl(ccCcc)ccnnnccccccccccccc5c===)=C)1O)1
# =12C(ccCCCClCCl[nH]CCcncncnnnccC)c)c4cc)3cc3Occ==O=O=O2OOOO1O
# ccccnnnnccoC)cssssnSSnSn)ccc)cc))cc)ccc[C@@H](Sc[N+]=1=O1
# 1C======CC(C[nH][C@@H]sCss5S5[C@@H]5cccClcc)cCccccccccC=c)==
# CC(Clc=CCCCCClClCl=)ClClSS[nH][nH][nH]Cl[I-]5nClc)ccc)c)ccCC)=OC((==
# (C((CCSSs(cN[nH][nH][nH]C\ssss[nH]n4cccC43cc3)c)cc)c=c)cO(c1OO)
# ClClCl(SCCCSC(CCl=S\Cl[nH][nH]cnnnnnnnCcc)cc3ccc33)=O=)O))1))1n
# 221)(nCCccsCCNSNs)[nH]=O)Cnccc5cccccccc=ccc[C@H][N+]==)=OO
# (n=CCCssN()Nss[C@@H]sssoc5cc5)5ccccccc(Cccccc)cccsCCCCC(
# C(CC((((CCCCCnncnnnOOOCOOCCCnnnc55cOccccccc)))=O1
# (C(((((((cc((c[C@@H]c(c(sccc5scccccccc(ccccccccccOcOO
# C(=N(ClClccCClClSccClc[nH]Sc)ccc))cccccccc3cc3[N-][N+]=[O-][O-]ONnNBr=OBrO
# =2C(((CC(Cl(==\SCS)[nH]SClScccccccncncccccccc=ccO
# c((((((Cl(CloSCsCSC[C@@H][C@@H][C@@H]C[C@@H]SCSsScccCccClc5cc==C)C)CCO(
# nNNNNNNNN[C@@H]ss[C@@H]sssc[C@@H][C@@H]scCc)c5Cc\cClccccccccccc=c=(c=
# 1O1Cn(ccCCCCsCCSOsSCCsC)Sscccccc)cCccC[C@H]CCCCCC
# Cl3)(((((((((()(cS)ccc(cc)cccccccccc)cOccOO
# C(((((((Cc((Cl(ScccSccnnn)ccccccccc)cc3)c(cccccBrcO)
# OSOOc(ClCClcSCnCl(Cl(C[nH]44Cn)ncc)ccccc)cccc((==)c
# nCCCCCnCCCSCCClscocc\5c55555cCccc)cc43c11
# 1212[C@H][C@@H]((ScClc(Cls(cccncnncccccccccccccccccC=OOOC)O1O)CO2OOO2O
# ((((((((((Cl(ClClClClClClcccc[nH]cClCl)ClccccccCc)cc==)====((OO
# =Cc[C@@H]([C@@H][C@@H]cCc(Clsc[C@@H][C@@H]ss=)s55ssc[I-]cClcccccc[I-]cC=cc[C@@H])=CC)(
# ClClClCl(-(ccc(cc)cccccccc\cCccccC)ccc)ccccC=)====OO=)O
# Cl2(c((()ccc(ccc\c4)4nnnnnncn[I-]ccCc)cc)[I-]ccCcc)cCccCCC
# C(=OCOCCCC(o[nH]COOCnnnnnnnnn)nClCnCcccccccccccccc)cccSN[O-]
# ClO21CcnnccNC(ClClClClSCnnnnnnClncccnc4n)cc3=(=)))1OO()
# 2[C@H]C1CCCNNClNCNccccOcC(\cccccc)cccC)c-cc3c===C(C(O
# C((((((((S(==ClClSSClSS[nH]nnc444cccc4ccc)cc))cOccCnn
# #CCC(((cS(SccCSs)ssSs)4cC5ccccccccc)ccCc)c[C@H]C(()
# (1=)c(ClSClCClClSCcc[nH]n)n4nnCnc33nc3cc3333c=O=OC=OOOO)1OO
# Cc=C=C=CCC=c(ClClccc[nH]c3cc5cc)cccccccccc)cccccc=c(OO22=OOOO)OO)
# Cc#CcClcc=c[nH]ccc[C@@H]OcCls5cc5ccCcClccc)ccc==)Sc==)==
# ((((cc[C@@H]cccc(cccccccccSccccc55ccccccccn)cc)c===O)1)
# CCC(OS(Cl(ccccScClc[nH][nH]ncc)ncccccc3cc33ccccO[I-]cCcCC3OOO
# sS(((((ClccSSSS(SSSS=cccccccc)cccc3ccccc1(==
# =((Cl((Cl((ccClClCCClCCl(([nH]C[nH]cnncC))[I-]cccccccCCccCCcC=
# n(C(CCC(nCcCcCccnccOOOClClcccccccClcccc=ccc==O11)11S11[O-]1
# cN[C@@H]NCCCCCCCCCCCssss[N-]Ss)Cl)ClClClClccc)cccc3c[C@H]33)c(11
# 1C===C====(CSCSScCC)CnnnC)n44cc33)3ccc)cccc1O
# ClC==CC(((CClClClSSSccccClcccccccccc3c3cc)CcccccOc)
# c((c(((cccCccss[nH]ss[nH]o[nH]55)c5ccccccc)cOc(O[C@@H][O-]OcC[C@H])O)(1
# OOO(C(OCC(NNc(cccncn(nnC4nc)cc)CcccClcc33Occ(cc)Nc(()1
# 21CC[C@@H][C@@H](C(((NCscClcccCCccCccc)cc)(ccc3Ccccccn==)=1
# CCC(([C@@H](([C@@H][C@H]())s[C@@H][C@@H][C@@H]CCs(sssccccccc\ccc3=c(C)CC=C
# nCCnnnCCC(cc(o[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]sS5ssc\)cccccc=3)==3==)1
# ccCcc(c(c(c((c(cc=cccccccccccccccccccc(=c==1)OOO=
# s[C@@H][C@@H]N)([C@@H]C[C@@H]ccCcccc4[C@@H][C@@H][C@@H][C@@H]=cccccccN)ccc[I-]cccccccc=C()(n1
# 2(((((((((((((((ClClccc(nnnncccccccccc)cccccccc11
# cc1((ccc((((((([C@@H][C@@H]S\CC\=\5ccccc)cc(cc3ccc===C====((
# cCc(((Cc((ccSS(SSSSSSOoScccccccccccc()c(3==)(c
# C=[C@H]CNCl(cNcNClc(NClcCl(4c(ncn3ncccCcccccccc)c=cncOO
# SCCSCSSSS(CSSOC[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]5c=55c5ccccccc(cc[N+]=====
# ==(((((Cl((O[C@@H][C@@H][C@@H][C@@H]\\CSS[C@@H]Cc\C\\\cCl5ccc)c==)((=OC))
# S==CCCC1NNCN(NONccOcccO3OnnClClccc3c3cc)cc)3C333c3)))))N
# S[C@@H][C@@H][C@@H]C[C@@H][C@@H]CCCsCSC[C@@H]CC[C@@H]ss[C@@H][C@@H]5s[C@@H][C@@H])cc)5c)cCcc4c=)OC=1(C=)==1
# =((((nn(c(s)[C@@H]cC[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]c5nncccccccccc3C[C@@H][C@@H][C@@H]11)111
# ccncnnosS[nH]sCs[C@H]S[C@@H]C[C@@H][C@@H][C@@H][C@@H]Cs5[C@@H]55cccc[I-]ccccOc[C@@H]cssO
# ===((=scc(\\Cl\c(\[nH]c[nH]c4n)ccc)4cccc3)3cccc)c1O)1
# Cl221[C@@H]((((()((ClClCl[nH]=nnnn5nncccncnccccCcccCO=OO)OOO
# CCC(CCCCCCCNsN\)[C@@H][C@@H][C@@H]c[C@@H]cc555ClccClc)c=5c[N-]c33))c[C@H]c2C22))=)[O-])11[O-][O-]1
# 2C==(=(cccClC=CcOc[nH][nH]c=cncCnCccccc)ccccccccccccOO
# ==((O(ccccSCl(\\Cl\)Cl))cc-ccccc33cccc=[O-][O-][O-][O-]OOO1OO
# ===O((ClcClClClClClSCScC[nH]Clcc[nH]ccnncCl)cc))cc(cCCcccnC=(
# ==((c((((((cccccccccccccccc4cccc3cCcccc)=((===O
# OCClCCCCCCC(cc[nH]C[nH][nH]4[nH]Cs55cccccccccCccccc([C@@H][C@@H]c1O1OO((((OOOO)O
# 2111[O-]ccSO(SCCCCcClco)44o[nH]c))cc)c)c3cccCc)ccO=nOO
# (C(112c(((ccccccncnnn)CnnCnncnccccccccc)cccc)c1
# CCOCC((C[C@@H]CCCCc[O-][O-]cccCO[C@@H]cnccccccc)ccccccccScc=)3))=[O-][O-]Br[O-]c
# 2==((((((Cl((Cl((Cl(cS)c)))cccccccccccccccc1=C)=(
# =Oc(c(((SCC(S(((\s[nH]s5[nH]occc)cccccccccccClccc)cC)cC
# C11([C@@H]C(Ss=scc(ccc)[I-]ccccccc)c4c3ccccc[I-]cc3=)))n))
# OCCC1)CCCCC[C@@H]c)3[C@@H][C@@H][C@@H][C@@H][C@@H]c[C@@H][C@@H]55)cccCl5c(ccccccsc=)(===
# ClCcOSSCCCCClClClClCl)ClClcClnnnClcccccccc3)3ccc11O))OO
# nnnnCnNsCsSCCCo[C@@H]cSccc5[nH]ccc555cccccCc3)cc===1[O-]1[O-][O-]
# sc))(cc[C@@H]cScC[nH]Oss[nH]sssCl6Clc555ccccccc)cCccCCcc
# CCC[C@@H]c(===4cClClClClCl=cCccc/ccccc3ccc)c3cccc=)c))))
# ((C=C(c(S(ClNCl(CCl\\ssc5[nH]ccccccccccccc)cc(c)c())=
# 11C(nnCcCCClcClcClClClSnnC)nC)nCnnn)Cl)cc3333cc)nnn
# 12CC(((Cl(ccN(ccc\ccccc)ccc3-34)ccccc3Oc3O)O(OOO)
# C[C@@H](ClccSSCcC\\\ccccC)[nH]=SccOc33c3ccccc=cC=OC=)O
# SOClCClCCCCC=OOOOsss555ss555c5\c)cccccccCCC))CC=FC
# sC=O[C@@H]sCNNCNN[C@@H][C@@H][C@@H][C@@H]ccc5oO)445cccc)cc)c(cccc3c)c
# CC[O-][C@@H]C((C(ClCl((\c((\([nH]S4o[nH]occccc4n)3c3[C@@H]=O=)3c)CO
# nCCC(ClClCCCCCClSCSCOSn555cO4cccccccOccCC3C(CCCCC
# Cc(cccccc[C@@H]css[C@H][C@@H]sSSssscccClccccccc3ccc)CcCCO()=1
# ccccnCcC(cccccc(Ccc[nH]/c\\cccccccccccCcccc3==1OO(
# ccCl(ClSCC(((((s=[nH][nH]=sssO)c)Ccccc[I-]cc4ccScccc=3==OO==
# (1()()cc(ccc(((c=Clc==cc)c)cCl)cccccccccccccO=)))CCO=3O)O
# 1ccC=cccncC\cc\[C@@H][C@@H]\\\[C@@H]\\\\\c5C\)3cccccccc)((c[C@H])c
# CCCC(cC(CCCsssSCSnCCno[nH]nn5cnCcc)C)ccccccCccccSc===11
# 1(1(((C1cccClCl()(c[nH]c[nH]cnc)nnnccccc333)c)3c1OOBr
# nc==CO-ccccncncccc)cccnncccccccccc)cc(33cOc==O
# cccccc1cc\sS[C@@H]ScsSSSS[C@@H]SS\ClnClClClSccccccccccc
# 11cc(ccCcccOOc[nH]o4s54s55s5cc55ccCccC3c3cccC((O([N-]))C)1(NBr=
# (((NNNNNNNNNNscccOOOOO[nH]1[nH][nH]c4ClccccccCl))))cccc)cc
# c=(CCC((c(c(cccc\\S[nH]ccccccccccccccc==c)
# CCC(((S(SSCcscC\C4[nH][nH]nCl(nCnnnc3ccccc)c3)333OOOOO
# ccCCCccCccSCSO=SccC[C@@H][C@@H][C@@H]c[C@@H][C@@H]ccc4cccccccOCCccO)=C1
# 11nn(S1S1S=Oc1cccccnOONn333=ccccccOcc333c3ccc)[C@H][C@H])))c([C@@H](S[O-][O-][O-]
# 1(C((cCCCCNCsC((cS(Clcnnnn)Cl4cc4cc)ccccccc)ccCnn
# O(((CSC(CccClSCcc[nH]cnncnncnncccccCcccccc3ccC))))Oc
# ==[O-]CC(S=[nH]=c(c\(\c[nH][nH]nnnn44n43cc3333c3O)c3c3O
# C2CcCc(cc((ClSCSSCSSScsSc)cccc)ccccc)cc)=C)cO=(OOOO)(O
# nnccnnnnClnClnoo)oooOn[nH]ClcCClc)cc)cccc3cccccc(=(
# (cnc((C((cCccc(cClcS)=ccc)ccccccccccccccccccCCCcCCO
# C===Cc((CCl(cc4ccccccc)5cc[I-]\cccccccccCc[C@@H]O((==)(O(=(OO(OOO(
# CC(=CC[C@@H]SN[C@H]s([C@H][C@H][C@@H]sO[C@@H]c[C@@H][C@@H]s[C@@H]ccOcc)ccccccccccC[C@H]======CC
# Clc1(((Cl(((c=\)s)Cln)Clnns4nnccnc3cc3333[N+]13O)3O[O-]1))
# 21)1cc((cccs)SScCCCCC[C@@H]5C[C@@H]CCCCCcccc4cccc=c=[C@H][C@H]=O11
# OcCCC(cc(((((Cl)(ccccnnn(cccccC4cccccc3C)COCc)=C=
# CcccnnCClC(ClClCl[nH]O[nH][nH][nH][nH]sOss555occcccccc==S=CCCCCC
# NNN(C(\(ClClClCl)ccClScCccccccccc33)cNccC)333(=3=3)===O((()OC
# ccCcCccccScOc([C@@H]SNSc[nH]nnnClc4cccc3c)33=3=[C@H]=====O=====
# cccnnnn(ocssscsssncnnncnClClcClccccccC3[C@H]32[C@H]=O==
# ==(O=(((SCCCCSSSSO=sOScc[C@@H]cccCcccccScCcCCC)CSCC[C@H]1)()(
# sCnnn=Cs[nH]sCsNsssss[C@@H]SCC[C@@H]cCscc[I-]cc5)cc[C@@H])[C@H]CC[C@H]c[C@H]=(1
# O1cnnCccccCl[nH]c=c4SS)S4\)Cl[nH]cc)cccccCcccccc))cC)CCOO)
# ClC===(-CN(c[C@@H][C@@H][C@@H]Cl[C@@H][C@@H][C@@H][C@@H][C@@H][C@@H]\\\\cSc)cc4cccc(CC[I-]CCCCCCOOnC
# nCC=OOCCCOO[C@H]oN4)occcccsccccccc=c=cccc33[C@H]3C[C@H])C=(
# Cl[C@@H]2[C@@H]((sCNC(((Cl=(ClCl[nH][nH])nncncccccc4cccc33OOccc))C)C))C
# cccccnccccccs[C@@H]s[C@@H][C@@H][C@@H][C@@H]S555555SccCc)cccc)Ccc[C@H]cccccc=
# 21N(c)C((NsCssssnnnccccCccncncncnC)ccc=33O==O)c)1
# 11C((NCCNN\sCClCl[nH]5SSSSSSsS)Sc))cc[N-]ccccc=cCC(=s1[C@H])=(=1
# =O((((((cccccOClo(nnnnnccncccCccccccc)c3c=33O==)))O
# #=(==(=CCCCNCSSSSssssssccccClClcClcccccc)C)(3c[N-]cSO2CCC()
# c([C@@H][C@@H]cc(Cl(cccSCS)[C@@H][C@@H]s[C@@H]sssS[C@@H]cccccCccccccc)c[C@@H]CC(n(
# =C((c=CsN((ClCcSClcccccc)cccccccccc)33c=)))Cc(((c(OO[O-]
# Br(OC(Cl((ClcClClcCl()S([nH]nc[nH]nn)nccn[I-]cccccccccc)ccc))c(OOc
# CCCCCC((NCl([C@@H]SClS\SScCccc\ccccccccccccccc==c[C@H]O(1O()(
# ===NN((cNN(((C\ClsCl[nH]c\cccCcccCcccccccccccc==c)[C@H](OOO1

# %%
total_gen, valid_gen, grammar_gen

# %%
noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

generated_image

# %%
decision = discriminator(generated_image)

decision.numpy()[0][0]
